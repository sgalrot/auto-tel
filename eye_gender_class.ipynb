# %% [markdown]
# <a href="https://colab.research.google.com/github/sgalrot/auto-tel/blob/main/eye_gender_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Eye Gender Classifier

# %% [markdown]
# ### Some Colab Setup
#
# Installing kaggle and downloading the dataset
#
# You should download the **kaggle.json** file from your kaggle account and upload it once prompted with "upload file"
#
# In case you are using local machine, just (not tested):
#
# 1) `pip install`
#
# 2) download dataset using `kaggle datasets download -d pavelbiz/eyes-rtte`

# %%
from os.path import exists, expanduser
if not exists(expanduser('~/.kaggle/kaggle.json')):
  # !pip install -q kaggle # type: ignore
  from google.colab import files 
  files.upload()
  # !mkdir ~/.kaggle # type: ignore
  # !cp kaggle.json ~/.kaggle/ # type: ignore
  # !chmod 600 ~/.kaggle/kaggle.json # type: ignore

# Downloading the dataset
# !kaggle datasets download -d pavelbiz/eyes-rtte
# !mkdir dataset
# !unzip eyes-rtte.zip -d ./dataset/
# Out:
#      <input type="file" id="files-cba08224-5ba1-46d0-a0df-45fd5c00dc9a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cba08224-5ba1-46d0-a0df-45fd5c00dc9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Streaming output truncated to the last 5000 lines.
#   inflating: ./dataset/maleeyes/2430.jpg
#   inflating: ./dataset/maleeyes/2431.jpg
#   inflating: ./dataset/maleeyes/2432.jpg
#   inflating: ./dataset/maleeyes/2433.jpg
#   inflating: ./dataset/maleeyes/2434.jpg
#   inflating: ./dataset/maleeyes/2435.jpg
#   inflating: ./dataset/maleeyes/2436.jpg
#   inflating: ./dataset/maleeyes/2437.jpg
#   inflating: ./dataset/maleeyes/2438.jpg
#   inflating: ./dataset/maleeyes/2439.jpg
#   inflating: ./dataset/maleeyes/244.jpg
#   inflating: ./dataset/maleeyes/2440.jpg
#   inflating: ./dataset/maleeyes/2441.jpg
#   inflating: ./dataset/maleeyes/2442.jpg
#   inflating: ./dataset/maleeyes/2443.jpg
#   inflating: ./dataset/maleeyes/2444.jpg
#   inflating: ./dataset/maleeyes/2445.jpg
#   inflating: ./dataset/maleeyes/2446.jpg
#   inflating: ./dataset/maleeyes/2448.jpg
#   inflating: ./dataset/maleeyes/2449.jpg
#   inflating: ./dataset/maleeyes/245.jpg
#   inflating: ./dataset/maleeyes/2450.jpg
#   inflating: ./dataset/maleeyes/2452.jpg
#   inflating: ./dataset/maleeyes/2453.jpg
#   inflating: ./dataset/maleeyes/2454.jpg
#   inflating: ./dataset/maleeyes/2455.jpg
#   inflating: ./dataset/maleeyes/2456.jpg
#   inflating: ./dataset/maleeyes/2457.jpg
#   inflating: ./dataset/maleeyes/2459.jpg
#   inflating: ./dataset/maleeyes/246.jpg
#   inflating: ./dataset/maleeyes/2460.jpg
#   inflating: ./dataset/maleeyes/2461.jpg
#   inflating: ./dataset/maleeyes/2462.jpg
#   inflating: ./dataset/maleeyes/2463.jpg
#   inflating: ./dataset/maleeyes/2464.jpg
#   inflating: ./dataset/maleeyes/2465.jpg
#   inflating: ./dataset/maleeyes/2466.jpg
#   inflating: ./dataset/maleeyes/2467.jpg
#   inflating: ./dataset/maleeyes/2469.jpg
#   inflating: ./dataset/maleeyes/247.jpg
#   inflating: ./dataset/maleeyes/2471.jpg
#   inflating: ./dataset/maleeyes/2472.jpg
#   inflating: ./dataset/maleeyes/2473.jpg
#   inflating: ./dataset/maleeyes/2474.jpg
#   inflating: ./dataset/maleeyes/2475.jpg
#   inflating: ./dataset/maleeyes/2477.jpg
#   inflating: ./dataset/maleeyes/2478.jpg
#   inflating: ./dataset/maleeyes/2479.jpg
#   inflating: ./dataset/maleeyes/2480.jpg
#   inflating: ./dataset/maleeyes/2481.jpg
#   inflating: ./dataset/maleeyes/2482.jpg
#   inflating: ./dataset/maleeyes/2483.jpg
#   inflating: ./dataset/maleeyes/2484.jpg
#   inflating: ./dataset/maleeyes/2485.jpg
#   inflating: ./dataset/maleeyes/2486.jpg
#   inflating: ./dataset/maleeyes/2487.jpg
#   inflating: ./dataset/maleeyes/2488.jpg
#   inflating: ./dataset/maleeyes/2489.jpg
#   inflating: ./dataset/maleeyes/249.jpg
#   inflating: ./dataset/maleeyes/2490.jpg
#   inflating: ./dataset/maleeyes/2491.jpg
#   inflating: ./dataset/maleeyes/2492.jpg
#   inflating: ./dataset/maleeyes/2493.jpg
#   inflating: ./dataset/maleeyes/2494.jpg
#   inflating: ./dataset/maleeyes/2495.jpg
#   inflating: ./dataset/maleeyes/2497.jpg
#   inflating: ./dataset/maleeyes/2498.jpg
#   inflating: ./dataset/maleeyes/2499.jpg
#   inflating: ./dataset/maleeyes/25.jpg
#   inflating: ./dataset/maleeyes/250.jpg
#   inflating: ./dataset/maleeyes/2500.jpg
#   inflating: ./dataset/maleeyes/2501.jpg
#   inflating: ./dataset/maleeyes/2502.jpg
#   inflating: ./dataset/maleeyes/2503.jpg
#   inflating: ./dataset/maleeyes/2504.jpg
#   inflating: ./dataset/maleeyes/2506.jpg
#   inflating: ./dataset/maleeyes/2507.jpg
#   inflating: ./dataset/maleeyes/2509.jpg
#   inflating: ./dataset/maleeyes/251.jpg
#   inflating: ./dataset/maleeyes/2511.jpg
#   inflating: ./dataset/maleeyes/2512.jpg
#   inflating: ./dataset/maleeyes/2513.jpg
#   inflating: ./dataset/maleeyes/2514.jpg
#   inflating: ./dataset/maleeyes/2515.jpg
#   inflating: ./dataset/maleeyes/2516.jpg
#   inflating: ./dataset/maleeyes/2517.jpg
#   inflating: ./dataset/maleeyes/2518.jpg
#   inflating: ./dataset/maleeyes/2519.jpg
#   inflating: ./dataset/maleeyes/252.jpg
#   inflating: ./dataset/maleeyes/2520.jpg
#   inflating: ./dataset/maleeyes/2521.jpg
#   inflating: ./dataset/maleeyes/2522.jpg
#   inflating: ./dataset/maleeyes/2523.jpg
#   inflating: ./dataset/maleeyes/2524.jpg
#   inflating: ./dataset/maleeyes/2525.jpg
#   inflating: ./dataset/maleeyes/2526.jpg
#   inflating: ./dataset/maleeyes/2527.jpg
#   inflating: ./dataset/maleeyes/2528.jpg
#   inflating: ./dataset/maleeyes/2529.jpg
#   inflating: ./dataset/maleeyes/253.jpg
#   inflating: ./dataset/maleeyes/2530.jpg
#   inflating: ./dataset/maleeyes/2531.jpg
#   inflating: ./dataset/maleeyes/2532.jpg
#   inflating: ./dataset/maleeyes/2533.jpg
#   inflating: ./dataset/maleeyes/2535.jpg
#   inflating: ./dataset/maleeyes/2536.jpg
#   inflating: ./dataset/maleeyes/2537.jpg
#   inflating: ./dataset/maleeyes/2538.jpg
#   inflating: ./dataset/maleeyes/2539.jpg
#   inflating: ./dataset/maleeyes/254.jpg
#   inflating: ./dataset/maleeyes/2540.jpg
#   inflating: ./dataset/maleeyes/2541.jpg
#   inflating: ./dataset/maleeyes/2542.jpg
#   inflating: ./dataset/maleeyes/2543.jpg
#   inflating: ./dataset/maleeyes/2544.jpg
#   inflating: ./dataset/maleeyes/2545.jpg
#   inflating: ./dataset/maleeyes/2547.jpg
#   inflating: ./dataset/maleeyes/2549.jpg
#   inflating: ./dataset/maleeyes/255.jpg
#   inflating: ./dataset/maleeyes/2550.jpg
#   inflating: ./dataset/maleeyes/2551.jpg
#   inflating: ./dataset/maleeyes/2552.jpg
#   inflating: ./dataset/maleeyes/2553.jpg
#   inflating: ./dataset/maleeyes/2554.jpg
#   inflating: ./dataset/maleeyes/2555.jpg
#   inflating: ./dataset/maleeyes/2556.jpg
#   inflating: ./dataset/maleeyes/2558.jpg
#   inflating: ./dataset/maleeyes/2559.jpg
#   inflating: ./dataset/maleeyes/256.jpg
#   inflating: ./dataset/maleeyes/2560.jpg
#   inflating: ./dataset/maleeyes/2563.jpg
#   inflating: ./dataset/maleeyes/2564.jpg
#   inflating: ./dataset/maleeyes/2565.jpg
#   inflating: ./dataset/maleeyes/2566.jpg
#   inflating: ./dataset/maleeyes/2568.jpg
#   inflating: ./dataset/maleeyes/2569.jpg
#   inflating: ./dataset/maleeyes/257.jpg
#   inflating: ./dataset/maleeyes/2570.jpg
#   inflating: ./dataset/maleeyes/2571.jpg
#   inflating: ./dataset/maleeyes/2572.jpg
#   inflating: ./dataset/maleeyes/2573.jpg
#   inflating: ./dataset/maleeyes/2574.jpg
#   inflating: ./dataset/maleeyes/2575.jpg
#   inflating: ./dataset/maleeyes/2576.jpg
#   inflating: ./dataset/maleeyes/2577.jpg
#   inflating: ./dataset/maleeyes/2578.jpg
#   inflating: ./dataset/maleeyes/2579.jpg
#   inflating: ./dataset/maleeyes/258.jpg
#   inflating: ./dataset/maleeyes/2580.jpg
#   inflating: ./dataset/maleeyes/2581.jpg
#   inflating: ./dataset/maleeyes/2582.jpg
#   inflating: ./dataset/maleeyes/2583.jpg
#   inflating: ./dataset/maleeyes/2584.jpg
#   inflating: ./dataset/maleeyes/2586.jpg
#   inflating: ./dataset/maleeyes/2587.jpg
#   inflating: ./dataset/maleeyes/2588.jpg
#   inflating: ./dataset/maleeyes/2593.jpg
#   inflating: ./dataset/maleeyes/2594.jpg
#   inflating: ./dataset/maleeyes/2595.jpg
#   inflating: ./dataset/maleeyes/2596.jpg
#   inflating: ./dataset/maleeyes/2597.jpg
#   inflating: ./dataset/maleeyes/2598.jpg
#   inflating: ./dataset/maleeyes/26.jpg
#   inflating: ./dataset/maleeyes/260.jpg
#   inflating: ./dataset/maleeyes/2601.jpg
#   inflating: ./dataset/maleeyes/2602.jpg
#   inflating: ./dataset/maleeyes/2603.jpg
#   inflating: ./dataset/maleeyes/2605.jpg
#   inflating: ./dataset/maleeyes/2607.jpg
#   inflating: ./dataset/maleeyes/2608.jpg
#   inflating: ./dataset/maleeyes/2609.jpg
#   inflating: ./dataset/maleeyes/261.jpg
#   inflating: ./dataset/maleeyes/2610.jpg
#   inflating: ./dataset/maleeyes/2611.jpg
#   inflating: ./dataset/maleeyes/2614.jpg
#   inflating: ./dataset/maleeyes/2615.jpg
#   inflating: ./dataset/maleeyes/2616.jpg
#   inflating: ./dataset/maleeyes/2617.jpg
#   inflating: ./dataset/maleeyes/2618.jpg
#   inflating: ./dataset/maleeyes/2619.jpg
#   inflating: ./dataset/maleeyes/262.jpg
#   inflating: ./dataset/maleeyes/2620.jpg
#   inflating: ./dataset/maleeyes/2621.jpg
#   inflating: ./dataset/maleeyes/2622.jpg
#   inflating: ./dataset/maleeyes/2623.jpg
#   inflating: ./dataset/maleeyes/2624.jpg
#   inflating: ./dataset/maleeyes/2625.jpg
#   inflating: ./dataset/maleeyes/2626.jpg
#   inflating: ./dataset/maleeyes/2627.jpg
#   inflating: ./dataset/maleeyes/2628.jpg
#   inflating: ./dataset/maleeyes/263.jpg
#   inflating: ./dataset/maleeyes/2633.jpg
#   inflating: ./dataset/maleeyes/2634.jpg
#   inflating: ./dataset/maleeyes/2635.jpg
#   inflating: ./dataset/maleeyes/2636.jpg
#   inflating: ./dataset/maleeyes/2637.jpg
#   inflating: ./dataset/maleeyes/2638.jpg
#   inflating: ./dataset/maleeyes/264.jpg
#   inflating: ./dataset/maleeyes/2641.jpg
#   inflating: ./dataset/maleeyes/2642.jpg
#   inflating: ./dataset/maleeyes/2646.jpg
#   inflating: ./dataset/maleeyes/2647.jpg
#   inflating: ./dataset/maleeyes/2648.jpg
#   inflating: ./dataset/maleeyes/2649.jpg
#   inflating: ./dataset/maleeyes/265.jpg
#   inflating: ./dataset/maleeyes/2650.jpg
#   inflating: ./dataset/maleeyes/2651.jpg
#   inflating: ./dataset/maleeyes/2652.jpg
#   inflating: ./dataset/maleeyes/2653.jpg
#   inflating: ./dataset/maleeyes/2654.jpg
#   inflating: ./dataset/maleeyes/2657.jpg
#   inflating: ./dataset/maleeyes/2658.jpg
#   inflating: ./dataset/maleeyes/2659.jpg
#   inflating: ./dataset/maleeyes/266.jpg
#   inflating: ./dataset/maleeyes/2660.jpg
#   inflating: ./dataset/maleeyes/2661.jpg
#   inflating: ./dataset/maleeyes/2662.jpg
#   inflating: ./dataset/maleeyes/2663.jpg
#   inflating: ./dataset/maleeyes/2664.jpg
#   inflating: ./dataset/maleeyes/2665.jpg
#   inflating: ./dataset/maleeyes/2666.jpg
#   inflating: ./dataset/maleeyes/2667.jpg
#   inflating: ./dataset/maleeyes/2668.jpg
#   inflating: ./dataset/maleeyes/2669.jpg
#   inflating: ./dataset/maleeyes/267.jpg
#   inflating: ./dataset/maleeyes/2670.jpg
#   inflating: ./dataset/maleeyes/2671.jpg
#   inflating: ./dataset/maleeyes/2672.jpg
#   inflating: ./dataset/maleeyes/2673.jpg
#   inflating: ./dataset/maleeyes/2674.jpg
#   inflating: ./dataset/maleeyes/2676.jpg
#   inflating: ./dataset/maleeyes/2677.jpg
#   inflating: ./dataset/maleeyes/2678.jpg
#   inflating: ./dataset/maleeyes/2679.jpg
#   inflating: ./dataset/maleeyes/268.jpg
#   inflating: ./dataset/maleeyes/2680.jpg
#   inflating: ./dataset/maleeyes/2681.jpg
#   inflating: ./dataset/maleeyes/2682.jpg
#   inflating: ./dataset/maleeyes/2683.jpg
#   inflating: ./dataset/maleeyes/2684.jpg
#   inflating: ./dataset/maleeyes/2685.jpg
#   inflating: ./dataset/maleeyes/2686.jpg
#   inflating: ./dataset/maleeyes/2687.jpg
#   inflating: ./dataset/maleeyes/2688.jpg
#   inflating: ./dataset/maleeyes/2689.jpg
#   inflating: ./dataset/maleeyes/269.jpg
#   inflating: ./dataset/maleeyes/2691.jpg
#   inflating: ./dataset/maleeyes/2692.jpg
#   inflating: ./dataset/maleeyes/2693.jpg
#   inflating: ./dataset/maleeyes/2695.jpg
#   inflating: ./dataset/maleeyes/2696.jpg
#   inflating: ./dataset/maleeyes/27.jpg
#   inflating: ./dataset/maleeyes/2701.jpg
#   inflating: ./dataset/maleeyes/2702.jpg
#   inflating: ./dataset/maleeyes/2703.jpg
#   inflating: ./dataset/maleeyes/2704.jpg
#   inflating: ./dataset/maleeyes/2705.jpg
#   inflating: ./dataset/maleeyes/2706.jpg
#   inflating: ./dataset/maleeyes/2707.jpg
#   inflating: ./dataset/maleeyes/2710.jpg
#   inflating: ./dataset/maleeyes/2711.jpg
#   inflating: ./dataset/maleeyes/2712.jpg
#   inflating: ./dataset/maleeyes/2713.jpg
#   inflating: ./dataset/maleeyes/2714.jpg
#   inflating: ./dataset/maleeyes/2715.jpg
#   inflating: ./dataset/maleeyes/2716.jpg
#   inflating: ./dataset/maleeyes/2717.jpg
#   inflating: ./dataset/maleeyes/2718.jpg
#   inflating: ./dataset/maleeyes/2719.jpg
#   inflating: ./dataset/maleeyes/272.jpg
#   inflating: ./dataset/maleeyes/2720.jpg
#   inflating: ./dataset/maleeyes/2721.jpg
#   inflating: ./dataset/maleeyes/2722.jpg
#   inflating: ./dataset/maleeyes/2723.jpg
#   inflating: ./dataset/maleeyes/2724.jpg
#   inflating: ./dataset/maleeyes/2725.jpg
#   inflating: ./dataset/maleeyes/2726.jpg
#   inflating: ./dataset/maleeyes/2727.jpg
#   inflating: ./dataset/maleeyes/2728.jpg
#   inflating: ./dataset/maleeyes/2729.jpg
#   inflating: ./dataset/maleeyes/273.jpg
#   inflating: ./dataset/maleeyes/2730.jpg
#   inflating: ./dataset/maleeyes/2731.jpg
#   inflating: ./dataset/maleeyes/2732.jpg
#   inflating: ./dataset/maleeyes/2733.jpg
#   inflating: ./dataset/maleeyes/2734.jpg
#   inflating: ./dataset/maleeyes/2735.jpg
#   inflating: ./dataset/maleeyes/2736.jpg
#   inflating: ./dataset/maleeyes/2738.jpg
#   inflating: ./dataset/maleeyes/2739.jpg
#   inflating: ./dataset/maleeyes/274.jpg
#   inflating: ./dataset/maleeyes/2740.jpg
#   inflating: ./dataset/maleeyes/2741.jpg
#   inflating: ./dataset/maleeyes/2742.jpg
#   inflating: ./dataset/maleeyes/2743.jpg
#   inflating: ./dataset/maleeyes/2744.jpg
#   inflating: ./dataset/maleeyes/2745.jpg
#   inflating: ./dataset/maleeyes/2747.jpg
#   inflating: ./dataset/maleeyes/2748.jpg
#   inflating: ./dataset/maleeyes/2749.jpg
#   inflating: ./dataset/maleeyes/275.jpg
#   inflating: ./dataset/maleeyes/2750.jpg
#   inflating: ./dataset/maleeyes/2751.jpg
#   inflating: ./dataset/maleeyes/2752.jpg
#   inflating: ./dataset/maleeyes/2753.jpg
#   inflating: ./dataset/maleeyes/2755.jpg
#   inflating: ./dataset/maleeyes/2756.jpg
#   inflating: ./dataset/maleeyes/2757.jpg
#   inflating: ./dataset/maleeyes/2759.jpg
#   inflating: ./dataset/maleeyes/276.jpg
#   inflating: ./dataset/maleeyes/2760.jpg
#   inflating: ./dataset/maleeyes/2761.jpg
#   inflating: ./dataset/maleeyes/2762.jpg
#   inflating: ./dataset/maleeyes/2763.jpg
#   inflating: ./dataset/maleeyes/2764.jpg
#   inflating: ./dataset/maleeyes/2765.jpg
#   inflating: ./dataset/maleeyes/2767.jpg
#   inflating: ./dataset/maleeyes/2768.jpg
#   inflating: ./dataset/maleeyes/2769.jpg
#   inflating: ./dataset/maleeyes/277.jpg
#   inflating: ./dataset/maleeyes/2770.jpg
#   inflating: ./dataset/maleeyes/2772.jpg
#   inflating: ./dataset/maleeyes/2773.jpg
#   inflating: ./dataset/maleeyes/2774.jpg
#   inflating: ./dataset/maleeyes/2775.jpg
#   inflating: ./dataset/maleeyes/2777.jpg
#   inflating: ./dataset/maleeyes/2779.jpg
#   inflating: ./dataset/maleeyes/278.jpg
#   inflating: ./dataset/maleeyes/2780.jpg
#   inflating: ./dataset/maleeyes/2781.jpg
#   inflating: ./dataset/maleeyes/2782.jpg
#   inflating: ./dataset/maleeyes/2783.jpg
#   inflating: ./dataset/maleeyes/2785.jpg
#   inflating: ./dataset/maleeyes/2786.jpg
#   inflating: ./dataset/maleeyes/2787.jpg
#   inflating: ./dataset/maleeyes/2788.jpg
#   inflating: ./dataset/maleeyes/279.jpg
#   inflating: ./dataset/maleeyes/2791.jpg
#   inflating: ./dataset/maleeyes/2792.jpg
#   inflating: ./dataset/maleeyes/2794.jpg
#   inflating: ./dataset/maleeyes/2795.jpg
#   inflating: ./dataset/maleeyes/2796.jpg
#   inflating: ./dataset/maleeyes/2797.jpg
#   inflating: ./dataset/maleeyes/2798.jpg
#   inflating: ./dataset/maleeyes/2799.jpg
#   inflating: ./dataset/maleeyes/28.jpg
#   inflating: ./dataset/maleeyes/280.jpg
#   inflating: ./dataset/maleeyes/2801.jpg
#   inflating: ./dataset/maleeyes/2802.jpg
#   inflating: ./dataset/maleeyes/2804.jpg
#   inflating: ./dataset/maleeyes/2805.jpg
#   inflating: ./dataset/maleeyes/2806.jpg
#   inflating: ./dataset/maleeyes/2807.jpg
#   inflating: ./dataset/maleeyes/2808.jpg
#   inflating: ./dataset/maleeyes/2809.jpg
#   inflating: ./dataset/maleeyes/281.jpg
#   inflating: ./dataset/maleeyes/2810.jpg
#   inflating: ./dataset/maleeyes/2811.jpg
#   inflating: ./dataset/maleeyes/2813.jpg
#   inflating: ./dataset/maleeyes/2816.jpg
#   inflating: ./dataset/maleeyes/2818.jpg
#   inflating: ./dataset/maleeyes/282.jpg
#   inflating: ./dataset/maleeyes/2821.jpg
#   inflating: ./dataset/maleeyes/2822.jpg
#   inflating: ./dataset/maleeyes/2823.jpg
#   inflating: ./dataset/maleeyes/2824.jpg
#   inflating: ./dataset/maleeyes/2827.jpg
#   inflating: ./dataset/maleeyes/2828.jpg
#   inflating: ./dataset/maleeyes/2829.jpg
#   inflating: ./dataset/maleeyes/283.jpg
#   inflating: ./dataset/maleeyes/2830.jpg
#   inflating: ./dataset/maleeyes/2833.jpg
#   inflating: ./dataset/maleeyes/2834.jpg
#   inflating: ./dataset/maleeyes/2835.jpg
#   inflating: ./dataset/maleeyes/2836.jpg
#   inflating: ./dataset/maleeyes/2839.jpg
#   inflating: ./dataset/maleeyes/2840.jpg
#   inflating: ./dataset/maleeyes/2841.jpg
#   inflating: ./dataset/maleeyes/2842.jpg
#   inflating: ./dataset/maleeyes/2843.jpg
#   inflating: ./dataset/maleeyes/2844.jpg
#   inflating: ./dataset/maleeyes/2845.jpg
#   inflating: ./dataset/maleeyes/2846.jpg
#   inflating: ./dataset/maleeyes/2847.jpg
#   inflating: ./dataset/maleeyes/2848.jpg
#   inflating: ./dataset/maleeyes/2849.jpg
#   inflating: ./dataset/maleeyes/285.jpg
#   inflating: ./dataset/maleeyes/2850.jpg
#   inflating: ./dataset/maleeyes/2851.jpg
#   inflating: ./dataset/maleeyes/2852.jpg
#   inflating: ./dataset/maleeyes/2855.jpg
#   inflating: ./dataset/maleeyes/2856.jpg
#   inflating: ./dataset/maleeyes/2857.jpg
#   inflating: ./dataset/maleeyes/2858.jpg
#   inflating: ./dataset/maleeyes/2859.jpg
#   inflating: ./dataset/maleeyes/286.jpg
#   inflating: ./dataset/maleeyes/2860.jpg
#   inflating: ./dataset/maleeyes/2861.jpg
#   inflating: ./dataset/maleeyes/2862.jpg
#   inflating: ./dataset/maleeyes/2864.jpg
#   inflating: ./dataset/maleeyes/2865.jpg
#   inflating: ./dataset/maleeyes/2868.jpg
#   inflating: ./dataset/maleeyes/2869.jpg
#   inflating: ./dataset/maleeyes/287.jpg
#   inflating: ./dataset/maleeyes/2871.jpg
#   inflating: ./dataset/maleeyes/2872.jpg
#   inflating: ./dataset/maleeyes/2873.jpg
#   inflating: ./dataset/maleeyes/2874.jpg
#   inflating: ./dataset/maleeyes/2875.jpg
#   inflating: ./dataset/maleeyes/2876.jpg
#   inflating: ./dataset/maleeyes/2877.jpg
#   inflating: ./dataset/maleeyes/2878.jpg
#   inflating: ./dataset/maleeyes/288.jpg
#   inflating: ./dataset/maleeyes/2880.jpg
#   inflating: ./dataset/maleeyes/2881.jpg
#   inflating: ./dataset/maleeyes/2882.jpg
#   inflating: ./dataset/maleeyes/2884.jpg
#   inflating: ./dataset/maleeyes/2886.jpg
#   inflating: ./dataset/maleeyes/2887.jpg
#   inflating: ./dataset/maleeyes/2888.jpg
#   inflating: ./dataset/maleeyes/2889.jpg
#   inflating: ./dataset/maleeyes/289.jpg
#   inflating: ./dataset/maleeyes/2892.jpg
#   inflating: ./dataset/maleeyes/2893.jpg
#   inflating: ./dataset/maleeyes/2894.jpg
#   inflating: ./dataset/maleeyes/2895.jpg
#   inflating: ./dataset/maleeyes/2896.jpg
#   inflating: ./dataset/maleeyes/2897.jpg
#   inflating: ./dataset/maleeyes/2898.jpg
#   inflating: ./dataset/maleeyes/2899.jpg
#   inflating: ./dataset/maleeyes/29.jpg
#   inflating: ./dataset/maleeyes/290.jpg
#   inflating: ./dataset/maleeyes/2900.jpg
#   inflating: ./dataset/maleeyes/2901.jpg
#   inflating: ./dataset/maleeyes/2902.jpg
#   inflating: ./dataset/maleeyes/2903.jpg
#   inflating: ./dataset/maleeyes/2904.jpg
#   inflating: ./dataset/maleeyes/2905.jpg
#   inflating: ./dataset/maleeyes/2906.jpg
#   inflating: ./dataset/maleeyes/2908.jpg
#   inflating: ./dataset/maleeyes/2909.jpg
#   inflating: ./dataset/maleeyes/2910.jpg
#   inflating: ./dataset/maleeyes/2911.jpg
#   inflating: ./dataset/maleeyes/2912.jpg
#   inflating: ./dataset/maleeyes/2913.jpg
#   inflating: ./dataset/maleeyes/2914.jpg
#   inflating: ./dataset/maleeyes/2915.jpg
#   inflating: ./dataset/maleeyes/2916.jpg
#   inflating: ./dataset/maleeyes/2917.jpg
#   inflating: ./dataset/maleeyes/2918.jpg
#   inflating: ./dataset/maleeyes/2919.jpg
#   inflating: ./dataset/maleeyes/292.jpg
#   inflating: ./dataset/maleeyes/2920.jpg
#   inflating: ./dataset/maleeyes/2921.jpg
#   inflating: ./dataset/maleeyes/2922.jpg
#   inflating: ./dataset/maleeyes/2923.jpg
#   inflating: ./dataset/maleeyes/2925.jpg
#   inflating: ./dataset/maleeyes/2926.jpg
#   inflating: ./dataset/maleeyes/2927.jpg
#   inflating: ./dataset/maleeyes/2928.jpg
#   inflating: ./dataset/maleeyes/2929.jpg
#   inflating: ./dataset/maleeyes/293.jpg
#   inflating: ./dataset/maleeyes/2931.jpg
#   inflating: ./dataset/maleeyes/2932.jpg
#   inflating: ./dataset/maleeyes/2933.jpg
#   inflating: ./dataset/maleeyes/2935.jpg
#   inflating: ./dataset/maleeyes/2936.jpg
#   inflating: ./dataset/maleeyes/2937.jpg
#   inflating: ./dataset/maleeyes/2938.jpg
#   inflating: ./dataset/maleeyes/2939.jpg
#   inflating: ./dataset/maleeyes/294.jpg
#   inflating: ./dataset/maleeyes/2940.jpg
#   inflating: ./dataset/maleeyes/2941.jpg
#   inflating: ./dataset/maleeyes/2942.jpg
#   inflating: ./dataset/maleeyes/2943.jpg
#   inflating: ./dataset/maleeyes/2944.jpg
#   inflating: ./dataset/maleeyes/2945.jpg
#   inflating: ./dataset/maleeyes/2946.jpg
#   inflating: ./dataset/maleeyes/2948.jpg
#   inflating: ./dataset/maleeyes/2949.jpg
#   inflating: ./dataset/maleeyes/295.jpg
#   inflating: ./dataset/maleeyes/2950.jpg
#   inflating: ./dataset/maleeyes/2951.jpg
#   inflating: ./dataset/maleeyes/2952.jpg
#   inflating: ./dataset/maleeyes/2953.jpg
#   inflating: ./dataset/maleeyes/2954.jpg
#   inflating: ./dataset/maleeyes/2957.jpg
#   inflating: ./dataset/maleeyes/2959.jpg
#   inflating: ./dataset/maleeyes/296.jpg
#   inflating: ./dataset/maleeyes/2960.jpg
#   inflating: ./dataset/maleeyes/2961.jpg
#   inflating: ./dataset/maleeyes/2962.jpg
#   inflating: ./dataset/maleeyes/2963.jpg
#   inflating: ./dataset/maleeyes/2964.jpg
#   inflating: ./dataset/maleeyes/2965.jpg
#   inflating: ./dataset/maleeyes/2966.jpg
#   inflating: ./dataset/maleeyes/2967.jpg
#   inflating: ./dataset/maleeyes/2968.jpg
#   inflating: ./dataset/maleeyes/2969.jpg
#   inflating: ./dataset/maleeyes/297.jpg
#   inflating: ./dataset/maleeyes/2970.jpg
#   inflating: ./dataset/maleeyes/2971.jpg
#   inflating: ./dataset/maleeyes/2972.jpg
#   inflating: ./dataset/maleeyes/2973.jpg
#   inflating: ./dataset/maleeyes/2974.jpg
#   inflating: ./dataset/maleeyes/2975.jpg
#   inflating: ./dataset/maleeyes/2976.jpg
#   inflating: ./dataset/maleeyes/2977.jpg
#   inflating: ./dataset/maleeyes/2978.jpg
#   inflating: ./dataset/maleeyes/298.jpg
#   inflating: ./dataset/maleeyes/2980.jpg
#   inflating: ./dataset/maleeyes/2981.jpg
#   inflating: ./dataset/maleeyes/2982.jpg
#   inflating: ./dataset/maleeyes/2983.jpg
#   inflating: ./dataset/maleeyes/2984.jpg
#   inflating: ./dataset/maleeyes/2985.jpg
#   inflating: ./dataset/maleeyes/2986.jpg
#   inflating: ./dataset/maleeyes/2987.jpg
#   inflating: ./dataset/maleeyes/2989.jpg
#   inflating: ./dataset/maleeyes/299.jpg
#   inflating: ./dataset/maleeyes/2990.jpg
#   inflating: ./dataset/maleeyes/2991.jpg
#   inflating: ./dataset/maleeyes/2992.jpg
#   inflating: ./dataset/maleeyes/2993.jpg
#   inflating: ./dataset/maleeyes/2994.jpg
#   inflating: ./dataset/maleeyes/2996.jpg
#   inflating: ./dataset/maleeyes/2997.jpg
#   inflating: ./dataset/maleeyes/2998.jpg
#   inflating: ./dataset/maleeyes/3000.jpg
#   inflating: ./dataset/maleeyes/3001.jpg
#   inflating: ./dataset/maleeyes/3002.jpg
#   inflating: ./dataset/maleeyes/3003.jpg
#   inflating: ./dataset/maleeyes/3004.jpg
#   inflating: ./dataset/maleeyes/3005.jpg
#   inflating: ./dataset/maleeyes/3006.jpg
#   inflating: ./dataset/maleeyes/3007.jpg
#   inflating: ./dataset/maleeyes/3008.jpg
#   inflating: ./dataset/maleeyes/301.jpg
#   inflating: ./dataset/maleeyes/3011.jpg
#   inflating: ./dataset/maleeyes/3012.jpg
#   inflating: ./dataset/maleeyes/3013.jpg
#   inflating: ./dataset/maleeyes/3014.jpg
#   inflating: ./dataset/maleeyes/3015.jpg
#   inflating: ./dataset/maleeyes/3016.jpg
#   inflating: ./dataset/maleeyes/3017.jpg
#   inflating: ./dataset/maleeyes/3018.jpg
#   inflating: ./dataset/maleeyes/3019.jpg
#   inflating: ./dataset/maleeyes/302.jpg
#   inflating: ./dataset/maleeyes/3020.jpg
#   inflating: ./dataset/maleeyes/3021.jpg
#   inflating: ./dataset/maleeyes/3022.jpg
#   inflating: ./dataset/maleeyes/3023.jpg
#   inflating: ./dataset/maleeyes/3024.jpg
#   inflating: ./dataset/maleeyes/3025.jpg
#   inflating: ./dataset/maleeyes/3026.jpg
#   inflating: ./dataset/maleeyes/3027.jpg
#   inflating: ./dataset/maleeyes/3028.jpg
#   inflating: ./dataset/maleeyes/3029.jpg
#   inflating: ./dataset/maleeyes/303.jpg
#   inflating: ./dataset/maleeyes/3030.jpg
#   inflating: ./dataset/maleeyes/3031.jpg
#   inflating: ./dataset/maleeyes/3032.jpg
#   inflating: ./dataset/maleeyes/3033.jpg
#   inflating: ./dataset/maleeyes/3034.jpg
#   inflating: ./dataset/maleeyes/3035.jpg
#   inflating: ./dataset/maleeyes/3036.jpg
#   inflating: ./dataset/maleeyes/3037.jpg
#   inflating: ./dataset/maleeyes/3038.jpg
#   inflating: ./dataset/maleeyes/304.jpg
#   inflating: ./dataset/maleeyes/3040.jpg
#   inflating: ./dataset/maleeyes/3041.jpg
#   inflating: ./dataset/maleeyes/3042.jpg
#   inflating: ./dataset/maleeyes/3043.jpg
#   inflating: ./dataset/maleeyes/3044.jpg
#   inflating: ./dataset/maleeyes/3045.jpg
#   inflating: ./dataset/maleeyes/3046.jpg
#   inflating: ./dataset/maleeyes/3048.jpg
#   inflating: ./dataset/maleeyes/3049.jpg
#   inflating: ./dataset/maleeyes/305.jpg
#   inflating: ./dataset/maleeyes/3050.jpg
#   inflating: ./dataset/maleeyes/3051.jpg
#   inflating: ./dataset/maleeyes/3052.jpg
#   inflating: ./dataset/maleeyes/3053.jpg
#   inflating: ./dataset/maleeyes/3054.jpg
#   inflating: ./dataset/maleeyes/3057.jpg
#   inflating: ./dataset/maleeyes/3058.jpg
#   inflating: ./dataset/maleeyes/3059.jpg
#   inflating: ./dataset/maleeyes/306.jpg
#   inflating: ./dataset/maleeyes/3060.jpg
#   inflating: ./dataset/maleeyes/3061.jpg
#   inflating: ./dataset/maleeyes/3062.jpg
#   inflating: ./dataset/maleeyes/3063.jpg
#   inflating: ./dataset/maleeyes/3064.jpg
#   inflating: ./dataset/maleeyes/3065.jpg
#   inflating: ./dataset/maleeyes/3067.jpg
#   inflating: ./dataset/maleeyes/3068.jpg
#   inflating: ./dataset/maleeyes/3069.jpg
#   inflating: ./dataset/maleeyes/307.jpg
#   inflating: ./dataset/maleeyes/3070.jpg
#   inflating: ./dataset/maleeyes/3071.jpg
#   inflating: ./dataset/maleeyes/3075.jpg
#   inflating: ./dataset/maleeyes/3076.jpg
#   inflating: ./dataset/maleeyes/3077.jpg
#   inflating: ./dataset/maleeyes/3078.jpg
#   inflating: ./dataset/maleeyes/3079.jpg
#   inflating: ./dataset/maleeyes/308.jpg
#   inflating: ./dataset/maleeyes/3080.jpg
#   inflating: ./dataset/maleeyes/3081.jpg
#   inflating: ./dataset/maleeyes/3082.jpg
#   inflating: ./dataset/maleeyes/3084.jpg
#   inflating: ./dataset/maleeyes/3085.jpg
#   inflating: ./dataset/maleeyes/3087.jpg
#   inflating: ./dataset/maleeyes/3088.jpg
#   inflating: ./dataset/maleeyes/3089.jpg
#   inflating: ./dataset/maleeyes/309.jpg
#   inflating: ./dataset/maleeyes/3090.jpg
#   inflating: ./dataset/maleeyes/3091.jpg
#   inflating: ./dataset/maleeyes/3092.jpg
#   inflating: ./dataset/maleeyes/3094.jpg
#   inflating: ./dataset/maleeyes/3095.jpg
#   inflating: ./dataset/maleeyes/3096.jpg
#   inflating: ./dataset/maleeyes/3097.jpg
#   inflating: ./dataset/maleeyes/3098.jpg
#   inflating: ./dataset/maleeyes/3099.jpg
#   inflating: ./dataset/maleeyes/31.jpg
#   inflating: ./dataset/maleeyes/310.jpg
#   inflating: ./dataset/maleeyes/3100.jpg
#   inflating: ./dataset/maleeyes/3101.jpg
#   inflating: ./dataset/maleeyes/3102.jpg
#   inflating: ./dataset/maleeyes/3103.jpg
#   inflating: ./dataset/maleeyes/3105.jpg
#   inflating: ./dataset/maleeyes/3106.jpg
#   inflating: ./dataset/maleeyes/3107.jpg
#   inflating: ./dataset/maleeyes/3108.jpg
#   inflating: ./dataset/maleeyes/3109.jpg
#   inflating: ./dataset/maleeyes/311.jpg
#   inflating: ./dataset/maleeyes/3110.jpg
#   inflating: ./dataset/maleeyes/3111.jpg
#   inflating: ./dataset/maleeyes/3112.jpg
#   inflating: ./dataset/maleeyes/3113.jpg
#   inflating: ./dataset/maleeyes/3114.jpg
#   inflating: ./dataset/maleeyes/3116.jpg
#   inflating: ./dataset/maleeyes/3117.jpg
#   inflating: ./dataset/maleeyes/3118.jpg
#   inflating: ./dataset/maleeyes/3119.jpg
#   inflating: ./dataset/maleeyes/3120.jpg
#   inflating: ./dataset/maleeyes/3121.jpg
#   inflating: ./dataset/maleeyes/3122.jpg
#   inflating: ./dataset/maleeyes/3123.jpg
#   inflating: ./dataset/maleeyes/3124.jpg
#   inflating: ./dataset/maleeyes/3125.jpg
#   inflating: ./dataset/maleeyes/3126.jpg
#   inflating: ./dataset/maleeyes/3127.jpg
#   inflating: ./dataset/maleeyes/3128.jpg
#   inflating: ./dataset/maleeyes/3129.jpg
#   inflating: ./dataset/maleeyes/313.jpg
#   inflating: ./dataset/maleeyes/3130.jpg
#   inflating: ./dataset/maleeyes/3131.jpg
#   inflating: ./dataset/maleeyes/3132.jpg
#   inflating: ./dataset/maleeyes/3133.jpg
#   inflating: ./dataset/maleeyes/3134.jpg
#   inflating: ./dataset/maleeyes/3136.jpg
#   inflating: ./dataset/maleeyes/3137.jpg
#   inflating: ./dataset/maleeyes/314.jpg
#   inflating: ./dataset/maleeyes/3141.jpg
#   inflating: ./dataset/maleeyes/3142.jpg
#   inflating: ./dataset/maleeyes/3143.jpg
#   inflating: ./dataset/maleeyes/3144.jpg
#   inflating: ./dataset/maleeyes/3145.jpg
#   inflating: ./dataset/maleeyes/3146.jpg
#   inflating: ./dataset/maleeyes/3147.jpg
#   inflating: ./dataset/maleeyes/3148.jpg
#   inflating: ./dataset/maleeyes/3149.jpg
#   inflating: ./dataset/maleeyes/315.jpg
#   inflating: ./dataset/maleeyes/3150.jpg
#   inflating: ./dataset/maleeyes/3152.jpg
#   inflating: ./dataset/maleeyes/3153.jpg
#   inflating: ./dataset/maleeyes/3154.jpg
#   inflating: ./dataset/maleeyes/3155.jpg
#   inflating: ./dataset/maleeyes/3156.jpg
#   inflating: ./dataset/maleeyes/3157.jpg
#   inflating: ./dataset/maleeyes/3158.jpg
#   inflating: ./dataset/maleeyes/3162.jpg
#   inflating: ./dataset/maleeyes/3163.jpg
#   inflating: ./dataset/maleeyes/3164.jpg
#   inflating: ./dataset/maleeyes/3165.jpg
#   inflating: ./dataset/maleeyes/3168.jpg
#   inflating: ./dataset/maleeyes/3169.jpg
#   inflating: ./dataset/maleeyes/317.jpg
#   inflating: ./dataset/maleeyes/3170.jpg
#   inflating: ./dataset/maleeyes/3171.jpg
#   inflating: ./dataset/maleeyes/3173.jpg
#   inflating: ./dataset/maleeyes/3175.jpg
#   inflating: ./dataset/maleeyes/3176.jpg
#   inflating: ./dataset/maleeyes/3177.jpg
#   inflating: ./dataset/maleeyes/3178.jpg
#   inflating: ./dataset/maleeyes/3179.jpg
#   inflating: ./dataset/maleeyes/318.jpg
#   inflating: ./dataset/maleeyes/3180.jpg
#   inflating: ./dataset/maleeyes/3181.jpg
#   inflating: ./dataset/maleeyes/3182.jpg
#   inflating: ./dataset/maleeyes/3183.jpg
#   inflating: ./dataset/maleeyes/3184.jpg
#   inflating: ./dataset/maleeyes/3185.jpg
#   inflating: ./dataset/maleeyes/3186.jpg
#   inflating: ./dataset/maleeyes/3187.jpg
#   inflating: ./dataset/maleeyes/3188.jpg
#   inflating: ./dataset/maleeyes/3189.jpg
#   inflating: ./dataset/maleeyes/319.jpg
#   inflating: ./dataset/maleeyes/3191.jpg
#   inflating: ./dataset/maleeyes/3193.jpg
#   inflating: ./dataset/maleeyes/3194.jpg
#   inflating: ./dataset/maleeyes/3195.jpg
#   inflating: ./dataset/maleeyes/3196.jpg
#   inflating: ./dataset/maleeyes/3197.jpg
#   inflating: ./dataset/maleeyes/3198.jpg
#   inflating: ./dataset/maleeyes/3199.jpg
#   inflating: ./dataset/maleeyes/32.jpg
#   inflating: ./dataset/maleeyes/320.jpg
#   inflating: ./dataset/maleeyes/3200.jpg
#   inflating: ./dataset/maleeyes/3201.jpg
#   inflating: ./dataset/maleeyes/3202.jpg
#   inflating: ./dataset/maleeyes/3203.jpg
#   inflating: ./dataset/maleeyes/3204.jpg
#   inflating: ./dataset/maleeyes/3205.jpg
#   inflating: ./dataset/maleeyes/3206.jpg
#   inflating: ./dataset/maleeyes/3207.jpg
#   inflating: ./dataset/maleeyes/3208.jpg
#   inflating: ./dataset/maleeyes/3209.jpg
#   inflating: ./dataset/maleeyes/3211.jpg
#   inflating: ./dataset/maleeyes/3212.jpg
#   inflating: ./dataset/maleeyes/3213.jpg
#   inflating: ./dataset/maleeyes/3214.jpg
#   inflating: ./dataset/maleeyes/3215.jpg
#   inflating: ./dataset/maleeyes/3216.jpg
#   inflating: ./dataset/maleeyes/3217.jpg
#   inflating: ./dataset/maleeyes/3218.jpg
#   inflating: ./dataset/maleeyes/3219.jpg
#   inflating: ./dataset/maleeyes/322.jpg
#   inflating: ./dataset/maleeyes/3220.jpg
#   inflating: ./dataset/maleeyes/3221.jpg
#   inflating: ./dataset/maleeyes/3222.jpg
#   inflating: ./dataset/maleeyes/3223.jpg
#   inflating: ./dataset/maleeyes/3224.jpg
#   inflating: ./dataset/maleeyes/3226.jpg
#   inflating: ./dataset/maleeyes/3227.jpg
#   inflating: ./dataset/maleeyes/3228.jpg
#   inflating: ./dataset/maleeyes/3229.jpg
#   inflating: ./dataset/maleeyes/323.jpg
#   inflating: ./dataset/maleeyes/3230.jpg
#   inflating: ./dataset/maleeyes/3231.jpg
#   inflating: ./dataset/maleeyes/3232.jpg
#   inflating: ./dataset/maleeyes/3233.jpg
#   inflating: ./dataset/maleeyes/3234.jpg
#   inflating: ./dataset/maleeyes/3235.jpg
#   inflating: ./dataset/maleeyes/3236.jpg
#   inflating: ./dataset/maleeyes/3237.jpg
#   inflating: ./dataset/maleeyes/3238.jpg
#   inflating: ./dataset/maleeyes/3239.jpg
#   inflating: ./dataset/maleeyes/324.jpg
#   inflating: ./dataset/maleeyes/3240.jpg
#   inflating: ./dataset/maleeyes/3241.jpg
#   inflating: ./dataset/maleeyes/3242.jpg
#   inflating: ./dataset/maleeyes/3243.jpg
#   inflating: ./dataset/maleeyes/3245.jpg
#   inflating: ./dataset/maleeyes/3246.jpg
#   inflating: ./dataset/maleeyes/3248.jpg
#   inflating: ./dataset/maleeyes/3249.jpg
#   inflating: ./dataset/maleeyes/325.jpg
#   inflating: ./dataset/maleeyes/3250.jpg
#   inflating: ./dataset/maleeyes/3251.jpg
#   inflating: ./dataset/maleeyes/3252.jpg
#   inflating: ./dataset/maleeyes/3253.jpg
#   inflating: ./dataset/maleeyes/3254.jpg
#   inflating: ./dataset/maleeyes/3255.jpg
#   inflating: ./dataset/maleeyes/3256.jpg
#   inflating: ./dataset/maleeyes/3258.jpg
#   inflating: ./dataset/maleeyes/3259.jpg
#   inflating: ./dataset/maleeyes/326.jpg
#   inflating: ./dataset/maleeyes/3261.jpg
#   inflating: ./dataset/maleeyes/3262.jpg
#   inflating: ./dataset/maleeyes/3266.jpg
#   inflating: ./dataset/maleeyes/3267.jpg
#   inflating: ./dataset/maleeyes/3268.jpg
#   inflating: ./dataset/maleeyes/3269.jpg
#   inflating: ./dataset/maleeyes/327.jpg
#   inflating: ./dataset/maleeyes/3270.jpg
#   inflating: ./dataset/maleeyes/3271.jpg
#   inflating: ./dataset/maleeyes/3272.jpg
#   inflating: ./dataset/maleeyes/3273.jpg
#   inflating: ./dataset/maleeyes/3274.jpg
#   inflating: ./dataset/maleeyes/3275.jpg
#   inflating: ./dataset/maleeyes/3276.jpg
#   inflating: ./dataset/maleeyes/3277.jpg
#   inflating: ./dataset/maleeyes/3278.jpg
#   inflating: ./dataset/maleeyes/3279.jpg
#   inflating: ./dataset/maleeyes/328.jpg
#   inflating: ./dataset/maleeyes/3280.jpg
#   inflating: ./dataset/maleeyes/3281.jpg
#   inflating: ./dataset/maleeyes/3282.jpg
#   inflating: ./dataset/maleeyes/3285.jpg
#   inflating: ./dataset/maleeyes/3286.jpg
#   inflating: ./dataset/maleeyes/3287.jpg
#   inflating: ./dataset/maleeyes/3288.jpg
#   inflating: ./dataset/maleeyes/3289.jpg
#   inflating: ./dataset/maleeyes/3290.jpg
#   inflating: ./dataset/maleeyes/3291.jpg
#   inflating: ./dataset/maleeyes/3292.jpg
#   inflating: ./dataset/maleeyes/3293.jpg
#   inflating: ./dataset/maleeyes/3294.jpg
#   inflating: ./dataset/maleeyes/3295.jpg
#   inflating: ./dataset/maleeyes/3296.jpg
#   inflating: ./dataset/maleeyes/3297.jpg
#   inflating: ./dataset/maleeyes/3298.jpg
#   inflating: ./dataset/maleeyes/3299.jpg
#   inflating: ./dataset/maleeyes/33.jpg
#   inflating: ./dataset/maleeyes/330.jpg
#   inflating: ./dataset/maleeyes/3301.jpg
#   inflating: ./dataset/maleeyes/3303.jpg
#   inflating: ./dataset/maleeyes/3304.jpg
#   inflating: ./dataset/maleeyes/3305.jpg
#   inflating: ./dataset/maleeyes/3306.jpg
#   inflating: ./dataset/maleeyes/3307.jpg
#   inflating: ./dataset/maleeyes/3308.jpg
#   inflating: ./dataset/maleeyes/3309.jpg
#   inflating: ./dataset/maleeyes/331.jpg
#   inflating: ./dataset/maleeyes/3310.jpg
#   inflating: ./dataset/maleeyes/3311.jpg
#   inflating: ./dataset/maleeyes/3312.jpg
#   inflating: ./dataset/maleeyes/3313.jpg
#   inflating: ./dataset/maleeyes/3314.jpg
#   inflating: ./dataset/maleeyes/3315.jpg
#   inflating: ./dataset/maleeyes/3316.jpg
#   inflating: ./dataset/maleeyes/3317.jpg
#   inflating: ./dataset/maleeyes/3318.jpg
#   inflating: ./dataset/maleeyes/332.jpg
#   inflating: ./dataset/maleeyes/3320.jpg
#   inflating: ./dataset/maleeyes/3322.jpg
#   inflating: ./dataset/maleeyes/3324.jpg
#   inflating: ./dataset/maleeyes/3325.jpg
#   inflating: ./dataset/maleeyes/3326.jpg
#   inflating: ./dataset/maleeyes/3329.jpg
#   inflating: ./dataset/maleeyes/333.jpg
#   inflating: ./dataset/maleeyes/3330.jpg
#   inflating: ./dataset/maleeyes/3331.jpg
#   inflating: ./dataset/maleeyes/3332.jpg
#   inflating: ./dataset/maleeyes/3333.jpg
#   inflating: ./dataset/maleeyes/3334.jpg
#   inflating: ./dataset/maleeyes/3335.jpg
#   inflating: ./dataset/maleeyes/3336.jpg
#   inflating: ./dataset/maleeyes/3337.jpg
#   inflating: ./dataset/maleeyes/3338.jpg
#   inflating: ./dataset/maleeyes/3339.jpg
#   inflating: ./dataset/maleeyes/334.jpg
#   inflating: ./dataset/maleeyes/3340.jpg
#   inflating: ./dataset/maleeyes/3341.jpg
#   inflating: ./dataset/maleeyes/3342.jpg
#   inflating: ./dataset/maleeyes/3343.jpg
#   inflating: ./dataset/maleeyes/3344.jpg
#   inflating: ./dataset/maleeyes/3345.jpg
#   inflating: ./dataset/maleeyes/3346.jpg
#   inflating: ./dataset/maleeyes/3347.jpg
#   inflating: ./dataset/maleeyes/3348.jpg
#   inflating: ./dataset/maleeyes/3349.jpg
#   inflating: ./dataset/maleeyes/335.jpg
#   inflating: ./dataset/maleeyes/3350.jpg
#   inflating: ./dataset/maleeyes/3351.jpg
#   inflating: ./dataset/maleeyes/3352.jpg
#   inflating: ./dataset/maleeyes/3353.jpg
#   inflating: ./dataset/maleeyes/3354.jpg
#   inflating: ./dataset/maleeyes/3355.jpg
#   inflating: ./dataset/maleeyes/3356.jpg
#   inflating: ./dataset/maleeyes/3357.jpg
#   inflating: ./dataset/maleeyes/3358.jpg
#   inflating: ./dataset/maleeyes/3359.jpg
#   inflating: ./dataset/maleeyes/336.jpg
#   inflating: ./dataset/maleeyes/3360.jpg
#   inflating: ./dataset/maleeyes/3361.jpg
#   inflating: ./dataset/maleeyes/3362.jpg
#   inflating: ./dataset/maleeyes/3363.jpg
#   inflating: ./dataset/maleeyes/3364.jpg
#   inflating: ./dataset/maleeyes/3365.jpg
#   inflating: ./dataset/maleeyes/3368.jpg
#   inflating: ./dataset/maleeyes/3369.jpg
#   inflating: ./dataset/maleeyes/337.jpg
#   inflating: ./dataset/maleeyes/3371.jpg
#   inflating: ./dataset/maleeyes/3372.jpg
#   inflating: ./dataset/maleeyes/3373.jpg
#   inflating: ./dataset/maleeyes/3374.jpg
#   inflating: ./dataset/maleeyes/3375.jpg
#   inflating: ./dataset/maleeyes/3376.jpg
#   inflating: ./dataset/maleeyes/3377.jpg
#   inflating: ./dataset/maleeyes/3378.jpg
#   inflating: ./dataset/maleeyes/3379.jpg
#   inflating: ./dataset/maleeyes/338.jpg
#   inflating: ./dataset/maleeyes/3382.jpg
#   inflating: ./dataset/maleeyes/3383.jpg
#   inflating: ./dataset/maleeyes/3384.jpg
#   inflating: ./dataset/maleeyes/3385.jpg
#   inflating: ./dataset/maleeyes/3386.jpg
#   inflating: ./dataset/maleeyes/3387.jpg
#   inflating: ./dataset/maleeyes/3388.jpg
#   inflating: ./dataset/maleeyes/3389.jpg
#   inflating: ./dataset/maleeyes/339.jpg
#   inflating: ./dataset/maleeyes/3390.jpg
#   inflating: ./dataset/maleeyes/3391.jpg
#   inflating: ./dataset/maleeyes/3392.jpg
#   inflating: ./dataset/maleeyes/3393.jpg
#   inflating: ./dataset/maleeyes/3394.jpg
#   inflating: ./dataset/maleeyes/3395.jpg
#   inflating: ./dataset/maleeyes/3397.jpg
#   inflating: ./dataset/maleeyes/3399.jpg
#   inflating: ./dataset/maleeyes/3400.jpg
#   inflating: ./dataset/maleeyes/3401.jpg
#   inflating: ./dataset/maleeyes/3402.jpg
#   inflating: ./dataset/maleeyes/3403.jpg
#   inflating: ./dataset/maleeyes/3404.jpg
#   inflating: ./dataset/maleeyes/3406.jpg
#   inflating: ./dataset/maleeyes/3408.jpg
#   inflating: ./dataset/maleeyes/3409.jpg
#   inflating: ./dataset/maleeyes/341.jpg
#   inflating: ./dataset/maleeyes/3410.jpg
#   inflating: ./dataset/maleeyes/3411.jpg
#   inflating: ./dataset/maleeyes/3412.jpg
#   inflating: ./dataset/maleeyes/3413.jpg
#   inflating: ./dataset/maleeyes/3414.jpg
#   inflating: ./dataset/maleeyes/3415.jpg
#   inflating: ./dataset/maleeyes/3416.jpg
#   inflating: ./dataset/maleeyes/3417.jpg
#   inflating: ./dataset/maleeyes/3418.jpg
#   inflating: ./dataset/maleeyes/3419.jpg
#   inflating: ./dataset/maleeyes/342.jpg
#   inflating: ./dataset/maleeyes/3420.jpg
#   inflating: ./dataset/maleeyes/3421.jpg
#   inflating: ./dataset/maleeyes/3422.jpg
#   inflating: ./dataset/maleeyes/3423.jpg
#   inflating: ./dataset/maleeyes/3424.jpg
#   inflating: ./dataset/maleeyes/3425.jpg
#   inflating: ./dataset/maleeyes/3427.jpg
#   inflating: ./dataset/maleeyes/3429.jpg
#   inflating: ./dataset/maleeyes/343.jpg
#   inflating: ./dataset/maleeyes/3430.jpg
#   inflating: ./dataset/maleeyes/3431.jpg
#   inflating: ./dataset/maleeyes/3432.jpg
#   inflating: ./dataset/maleeyes/3433.jpg
#   inflating: ./dataset/maleeyes/3434.jpg
#   inflating: ./dataset/maleeyes/3435.jpg
#   inflating: ./dataset/maleeyes/3436.jpg
#   inflating: ./dataset/maleeyes/3438.jpg
#   inflating: ./dataset/maleeyes/3439.jpg
#   inflating: ./dataset/maleeyes/344.jpg
#   inflating: ./dataset/maleeyes/3440.jpg
#   inflating: ./dataset/maleeyes/3441.jpg
#   inflating: ./dataset/maleeyes/3442.jpg
#   inflating: ./dataset/maleeyes/3443.jpg
#   inflating: ./dataset/maleeyes/3444.jpg
#   inflating: ./dataset/maleeyes/3445.jpg
#   inflating: ./dataset/maleeyes/3446.jpg
#   inflating: ./dataset/maleeyes/3447.jpg
#   inflating: ./dataset/maleeyes/3448.jpg
#   inflating: ./dataset/maleeyes/3449.jpg
#   inflating: ./dataset/maleeyes/345.jpg
#   inflating: ./dataset/maleeyes/3450.jpg
#   inflating: ./dataset/maleeyes/3451.jpg
#   inflating: ./dataset/maleeyes/3452.jpg
#   inflating: ./dataset/maleeyes/3454.jpg
#   inflating: ./dataset/maleeyes/3455.jpg
#   inflating: ./dataset/maleeyes/3456.jpg
#   inflating: ./dataset/maleeyes/3457.jpg
#   inflating: ./dataset/maleeyes/3458.jpg
#   inflating: ./dataset/maleeyes/3459.jpg
#   inflating: ./dataset/maleeyes/346.jpg
#   inflating: ./dataset/maleeyes/3460.jpg
#   inflating: ./dataset/maleeyes/3461.jpg
#   inflating: ./dataset/maleeyes/3462.jpg
#   inflating: ./dataset/maleeyes/3463.jpg
#   inflating: ./dataset/maleeyes/3464.jpg
#   inflating: ./dataset/maleeyes/3465.jpg
#   inflating: ./dataset/maleeyes/3466.jpg
#   inflating: ./dataset/maleeyes/3467.jpg
#   inflating: ./dataset/maleeyes/3468.jpg
#   inflating: ./dataset/maleeyes/3469.jpg
#   inflating: ./dataset/maleeyes/347.jpg
#   inflating: ./dataset/maleeyes/3470.jpg
#   inflating: ./dataset/maleeyes/3472.jpg
#   inflating: ./dataset/maleeyes/3474.jpg
#   inflating: ./dataset/maleeyes/3475.jpg
#   inflating: ./dataset/maleeyes/3476.jpg
#   inflating: ./dataset/maleeyes/3477.jpg
#   inflating: ./dataset/maleeyes/3478.jpg
#   inflating: ./dataset/maleeyes/3479.jpg
#   inflating: ./dataset/maleeyes/348.jpg
#   inflating: ./dataset/maleeyes/3480.jpg
#   inflating: ./dataset/maleeyes/3481.jpg
#   inflating: ./dataset/maleeyes/3482.jpg
#   inflating: ./dataset/maleeyes/3483.jpg
#   inflating: ./dataset/maleeyes/3484.jpg
#   inflating: ./dataset/maleeyes/3485.jpg
#   inflating: ./dataset/maleeyes/3486.jpg
#   inflating: ./dataset/maleeyes/3487.jpg
#   inflating: ./dataset/maleeyes/3488.jpg
#   inflating: ./dataset/maleeyes/3489.jpg
#   inflating: ./dataset/maleeyes/349.jpg
#   inflating: ./dataset/maleeyes/3490.jpg
#   inflating: ./dataset/maleeyes/3491.jpg
#   inflating: ./dataset/maleeyes/3492.jpg
#   inflating: ./dataset/maleeyes/3493.jpg
#   inflating: ./dataset/maleeyes/3494.jpg
#   inflating: ./dataset/maleeyes/3495.jpg
#   inflating: ./dataset/maleeyes/3496.jpg
#   inflating: ./dataset/maleeyes/3497.jpg
#   inflating: ./dataset/maleeyes/3498.jpg
#   inflating: ./dataset/maleeyes/3499.jpg
#   inflating: ./dataset/maleeyes/35.jpg
#   inflating: ./dataset/maleeyes/350.jpg
#   inflating: ./dataset/maleeyes/3500.jpg
#   inflating: ./dataset/maleeyes/3501.jpg
#   inflating: ./dataset/maleeyes/3502.jpg
#   inflating: ./dataset/maleeyes/3503.jpg
#   inflating: ./dataset/maleeyes/3504.jpg
#   inflating: ./dataset/maleeyes/3505.jpg
#   inflating: ./dataset/maleeyes/3506.jpg
#   inflating: ./dataset/maleeyes/3508.jpg
#   inflating: ./dataset/maleeyes/3509.jpg
#   inflating: ./dataset/maleeyes/351.jpg
#   inflating: ./dataset/maleeyes/3510.jpg
#   inflating: ./dataset/maleeyes/3511.jpg
#   inflating: ./dataset/maleeyes/3512.jpg
#   inflating: ./dataset/maleeyes/3514.jpg
#   inflating: ./dataset/maleeyes/3515.jpg
#   inflating: ./dataset/maleeyes/3517.jpg
#   inflating: ./dataset/maleeyes/3518.jpg
#   inflating: ./dataset/maleeyes/3519.jpg
#   inflating: ./dataset/maleeyes/352.jpg
#   inflating: ./dataset/maleeyes/3520.jpg
#   inflating: ./dataset/maleeyes/3525.jpg
#   inflating: ./dataset/maleeyes/3526.jpg
#   inflating: ./dataset/maleeyes/3527.jpg
#   inflating: ./dataset/maleeyes/3528.jpg
#   inflating: ./dataset/maleeyes/3529.jpg
#   inflating: ./dataset/maleeyes/353.jpg
#   inflating: ./dataset/maleeyes/3530.jpg
#   inflating: ./dataset/maleeyes/3532.jpg
#   inflating: ./dataset/maleeyes/3533.jpg
#   inflating: ./dataset/maleeyes/3534.jpg
#   inflating: ./dataset/maleeyes/3535.jpg
#   inflating: ./dataset/maleeyes/3536.jpg
#   inflating: ./dataset/maleeyes/3537.jpg
#   inflating: ./dataset/maleeyes/3538.jpg
#   inflating: ./dataset/maleeyes/3539.jpg
#   inflating: ./dataset/maleeyes/354.jpg
#   inflating: ./dataset/maleeyes/3540.jpg
#   inflating: ./dataset/maleeyes/3541.jpg
#   inflating: ./dataset/maleeyes/3544.jpg
#   inflating: ./dataset/maleeyes/3545.jpg
#   inflating: ./dataset/maleeyes/3546.jpg
#   inflating: ./dataset/maleeyes/3548.jpg
#   inflating: ./dataset/maleeyes/3549.jpg
#   inflating: ./dataset/maleeyes/355.jpg
#   inflating: ./dataset/maleeyes/3550.jpg
#   inflating: ./dataset/maleeyes/3551.jpg
#   inflating: ./dataset/maleeyes/3552.jpg
#   inflating: ./dataset/maleeyes/3553.jpg
#   inflating: ./dataset/maleeyes/3554.jpg
#   inflating: ./dataset/maleeyes/3555.jpg
#   inflating: ./dataset/maleeyes/3556.jpg
#   inflating: ./dataset/maleeyes/3557.jpg
#   inflating: ./dataset/maleeyes/3558.jpg
#   inflating: ./dataset/maleeyes/3559.jpg
#   inflating: ./dataset/maleeyes/356.jpg
#   inflating: ./dataset/maleeyes/3561.jpg
#   inflating: ./dataset/maleeyes/3562.jpg
#   inflating: ./dataset/maleeyes/3563.jpg
#   inflating: ./dataset/maleeyes/3564.jpg
#   inflating: ./dataset/maleeyes/3565.jpg
#   inflating: ./dataset/maleeyes/3566.jpg
#   inflating: ./dataset/maleeyes/3567.jpg
#   inflating: ./dataset/maleeyes/3568.jpg
#   inflating: ./dataset/maleeyes/3569.jpg
#   inflating: ./dataset/maleeyes/357.jpg
#   inflating: ./dataset/maleeyes/3570.jpg
#   inflating: ./dataset/maleeyes/3571.jpg
#   inflating: ./dataset/maleeyes/3572.jpg
#   inflating: ./dataset/maleeyes/3573.jpg
#   inflating: ./dataset/maleeyes/3574.jpg
#   inflating: ./dataset/maleeyes/3575.jpg
#   inflating: ./dataset/maleeyes/3576.jpg
#   inflating: ./dataset/maleeyes/3577.jpg
#   inflating: ./dataset/maleeyes/3578.jpg
#   inflating: ./dataset/maleeyes/3579.jpg
#   inflating: ./dataset/maleeyes/358.jpg
#   inflating: ./dataset/maleeyes/3580.jpg
#   inflating: ./dataset/maleeyes/3581.jpg
#   inflating: ./dataset/maleeyes/3582.jpg
#   inflating: ./dataset/maleeyes/3583.jpg
#   inflating: ./dataset/maleeyes/3584.jpg
#   inflating: ./dataset/maleeyes/3585.jpg
#   inflating: ./dataset/maleeyes/3586.jpg
#   inflating: ./dataset/maleeyes/3587.jpg
#   inflating: ./dataset/maleeyes/3588.jpg
#   inflating: ./dataset/maleeyes/3589.jpg
#   inflating: ./dataset/maleeyes/3590.jpg
#   inflating: ./dataset/maleeyes/3591.jpg
#   inflating: ./dataset/maleeyes/3592.jpg
#   inflating: ./dataset/maleeyes/3593.jpg
#   inflating: ./dataset/maleeyes/3594.jpg
#   inflating: ./dataset/maleeyes/3595.jpg
#   inflating: ./dataset/maleeyes/36.jpg
# ...
#   inflating: ./dataset/maleeyes/7293.jpg
#   inflating: ./dataset/maleeyes/7294.jpg
#   inflating: ./dataset/maleeyes/7295.jpg
#   inflating: ./dataset/maleeyes/7296.jpg
#   inflating: ./dataset/maleeyes/7297.jpg
#   inflating: ./dataset/maleeyes/73.jpg
#   inflating: ./dataset/maleeyes/730.jpg
#   inflating: ./dataset/maleeyes/7300.jpg
#   inflating: ./dataset/maleeyes/7301.jpg
#   inflating: ./dataset/maleeyes/7302.jpg
#   inflating: ./dataset/maleeyes/7303.jpg
#   inflating: ./dataset/maleeyes/7304.jpg
#   inflating: ./dataset/maleeyes/7305.jpg
#   inflating: ./dataset/maleeyes/7306.jpg
#   inflating: ./dataset/maleeyes/7307.jpg
#   inflating: ./dataset/maleeyes/7308.jpg
#   inflating: ./dataset/maleeyes/731.jpg
#   inflating: ./dataset/maleeyes/7310.jpg
#   inflating: ./dataset/maleeyes/7311.jpg
#   inflating: ./dataset/maleeyes/7312.jpg
#   inflating: ./dataset/maleeyes/7313.jpg
#   inflating: ./dataset/maleeyes/7314.jpg
#   inflating: ./dataset/maleeyes/7315.jpg
#   inflating: ./dataset/maleeyes/7317.jpg
#   inflating: ./dataset/maleeyes/7318.jpg
#   inflating: ./dataset/maleeyes/732.jpg
#   inflating: ./dataset/maleeyes/7320.jpg
#   inflating: ./dataset/maleeyes/7321.jpg
#   inflating: ./dataset/maleeyes/7322.jpg
#   inflating: ./dataset/maleeyes/7323.jpg
#   inflating: ./dataset/maleeyes/7324.jpg
#   inflating: ./dataset/maleeyes/7325.jpg
#   inflating: ./dataset/maleeyes/7326.jpg
#   inflating: ./dataset/maleeyes/7327.jpg
#   inflating: ./dataset/maleeyes/7328.jpg
#   inflating: ./dataset/maleeyes/7329.jpg
#   inflating: ./dataset/maleeyes/733.jpg
#   inflating: ./dataset/maleeyes/7332.jpg
#   inflating: ./dataset/maleeyes/7333.jpg
#   inflating: ./dataset/maleeyes/7334.jpg
#   inflating: ./dataset/maleeyes/7336.jpg
#   inflating: ./dataset/maleeyes/7337.jpg
#   inflating: ./dataset/maleeyes/7338.jpg
#   inflating: ./dataset/maleeyes/7339.jpg
#   inflating: ./dataset/maleeyes/734.jpg
#   inflating: ./dataset/maleeyes/7340.jpg
#   inflating: ./dataset/maleeyes/7341.jpg
#   inflating: ./dataset/maleeyes/7342.jpg
#   inflating: ./dataset/maleeyes/7343.jpg
#   inflating: ./dataset/maleeyes/7344.jpg
#   inflating: ./dataset/maleeyes/7345.jpg
#   inflating: ./dataset/maleeyes/7346.jpg
#   inflating: ./dataset/maleeyes/7347.jpg
#   inflating: ./dataset/maleeyes/7348.jpg
#   inflating: ./dataset/maleeyes/7349.jpg
#   inflating: ./dataset/maleeyes/735.jpg
#   inflating: ./dataset/maleeyes/7350.jpg
#   inflating: ./dataset/maleeyes/7351.jpg
#   inflating: ./dataset/maleeyes/7352.jpg
#   inflating: ./dataset/maleeyes/7353.jpg
#   inflating: ./dataset/maleeyes/7354.jpg
#   inflating: ./dataset/maleeyes/7355.jpg
#   inflating: ./dataset/maleeyes/7356.jpg
#   inflating: ./dataset/maleeyes/7357.jpg
#   inflating: ./dataset/maleeyes/7358.jpg
#   inflating: ./dataset/maleeyes/736.jpg
#   inflating: ./dataset/maleeyes/7360.jpg
#   inflating: ./dataset/maleeyes/7361.jpg
#   inflating: ./dataset/maleeyes/7362.jpg
#   inflating: ./dataset/maleeyes/7363.jpg
#   inflating: ./dataset/maleeyes/7364.jpg
#   inflating: ./dataset/maleeyes/7365.jpg
#   inflating: ./dataset/maleeyes/7366.jpg
#   inflating: ./dataset/maleeyes/7368.jpg
#   inflating: ./dataset/maleeyes/7369.jpg
#   inflating: ./dataset/maleeyes/7370.jpg
#   inflating: ./dataset/maleeyes/7371.jpg
#   inflating: ./dataset/maleeyes/7372.jpg
#   inflating: ./dataset/maleeyes/7374.jpg
#   inflating: ./dataset/maleeyes/7375.jpg
#   inflating: ./dataset/maleeyes/7378.jpg
#   inflating: ./dataset/maleeyes/7379.jpg
#   inflating: ./dataset/maleeyes/738.jpg
#   inflating: ./dataset/maleeyes/7380.jpg
#   inflating: ./dataset/maleeyes/7381.jpg
#   inflating: ./dataset/maleeyes/7382.jpg
#   inflating: ./dataset/maleeyes/7383.jpg
#   inflating: ./dataset/maleeyes/7384.jpg
#   inflating: ./dataset/maleeyes/7385.jpg
#   inflating: ./dataset/maleeyes/7386.jpg
#   inflating: ./dataset/maleeyes/7387.jpg
#   inflating: ./dataset/maleeyes/7388.jpg
#   inflating: ./dataset/maleeyes/7389.jpg
#   inflating: ./dataset/maleeyes/739.jpg
#   inflating: ./dataset/maleeyes/7390.jpg
#   inflating: ./dataset/maleeyes/7391.jpg
#   inflating: ./dataset/maleeyes/7396.jpg
#   inflating: ./dataset/maleeyes/7397.jpg
#   inflating: ./dataset/maleeyes/7398.jpg
#   inflating: ./dataset/maleeyes/74.jpg
#   inflating: ./dataset/maleeyes/740.jpg
#   inflating: ./dataset/maleeyes/7400.jpg
#   inflating: ./dataset/maleeyes/7401.jpg
#   inflating: ./dataset/maleeyes/7402.jpg
#   inflating: ./dataset/maleeyes/7403.jpg
#   inflating: ./dataset/maleeyes/7404.jpg
#   inflating: ./dataset/maleeyes/7405.jpg
#   inflating: ./dataset/maleeyes/7406.jpg
#   inflating: ./dataset/maleeyes/7407.jpg
#   inflating: ./dataset/maleeyes/7408.jpg
#   inflating: ./dataset/maleeyes/7409.jpg
#   inflating: ./dataset/maleeyes/741.jpg
#   inflating: ./dataset/maleeyes/7410.jpg
#   inflating: ./dataset/maleeyes/7411.jpg
#   inflating: ./dataset/maleeyes/7412.jpg
#   inflating: ./dataset/maleeyes/7414.jpg
#   inflating: ./dataset/maleeyes/7415.jpg
#   inflating: ./dataset/maleeyes/7416.jpg
#   inflating: ./dataset/maleeyes/7419.jpg
#   inflating: ./dataset/maleeyes/742.jpg
#   inflating: ./dataset/maleeyes/7420.jpg
#   inflating: ./dataset/maleeyes/7421.jpg
#   inflating: ./dataset/maleeyes/7422.jpg
#   inflating: ./dataset/maleeyes/7423.jpg
#   inflating: ./dataset/maleeyes/7424.jpg
#   inflating: ./dataset/maleeyes/7425.jpg
#   inflating: ./dataset/maleeyes/7426.jpg
#   inflating: ./dataset/maleeyes/7427.jpg
#   inflating: ./dataset/maleeyes/7428.jpg
#   inflating: ./dataset/maleeyes/743.jpg
#   inflating: ./dataset/maleeyes/7432.jpg
#   inflating: ./dataset/maleeyes/7433.jpg
#   inflating: ./dataset/maleeyes/7434.jpg
#   inflating: ./dataset/maleeyes/7435.jpg
#   inflating: ./dataset/maleeyes/7436.jpg
#   inflating: ./dataset/maleeyes/7437.jpg
#   inflating: ./dataset/maleeyes/744.jpg
#   inflating: ./dataset/maleeyes/745.jpg
#   inflating: ./dataset/maleeyes/748.jpg
#   inflating: ./dataset/maleeyes/75.jpg
#   inflating: ./dataset/maleeyes/751.jpg
#   inflating: ./dataset/maleeyes/752.jpg
#   inflating: ./dataset/maleeyes/753.jpg
#   inflating: ./dataset/maleeyes/755.jpg
#   inflating: ./dataset/maleeyes/756.jpg
#   inflating: ./dataset/maleeyes/758.jpg
#   inflating: ./dataset/maleeyes/759.jpg
#   inflating: ./dataset/maleeyes/76.jpg
#   inflating: ./dataset/maleeyes/760.jpg
#   inflating: ./dataset/maleeyes/762.jpg
#   inflating: ./dataset/maleeyes/763.jpg
#   inflating: ./dataset/maleeyes/764.jpg
#   inflating: ./dataset/maleeyes/768.jpg
#   inflating: ./dataset/maleeyes/769.jpg
#   inflating: ./dataset/maleeyes/77.jpg
#   inflating: ./dataset/maleeyes/770.jpg
#   inflating: ./dataset/maleeyes/771.jpg
#   inflating: ./dataset/maleeyes/772.jpg
#   inflating: ./dataset/maleeyes/773.jpg
#   inflating: ./dataset/maleeyes/776.jpg
#   inflating: ./dataset/maleeyes/777.jpg
#   inflating: ./dataset/maleeyes/78.jpg
#   inflating: ./dataset/maleeyes/780.jpg
#   inflating: ./dataset/maleeyes/781.jpg
#   inflating: ./dataset/maleeyes/782.jpg
#   inflating: ./dataset/maleeyes/783.jpg
#   inflating: ./dataset/maleeyes/784.jpg
#   inflating: ./dataset/maleeyes/785.jpg
#   inflating: ./dataset/maleeyes/786.jpg
#   inflating: ./dataset/maleeyes/787.jpg
#   inflating: ./dataset/maleeyes/788.jpg
#   inflating: ./dataset/maleeyes/789.jpg
#   inflating: ./dataset/maleeyes/79.jpg
#   inflating: ./dataset/maleeyes/790.jpg
#   inflating: ./dataset/maleeyes/791.jpg
#   inflating: ./dataset/maleeyes/792.jpg
#   inflating: ./dataset/maleeyes/796.jpg
#   inflating: ./dataset/maleeyes/798.jpg
#   inflating: ./dataset/maleeyes/799.jpg
#   inflating: ./dataset/maleeyes/8.jpg
#   inflating: ./dataset/maleeyes/80.jpg
#   inflating: ./dataset/maleeyes/800.jpg
#   inflating: ./dataset/maleeyes/801.jpg
#   inflating: ./dataset/maleeyes/802.jpg
#   inflating: ./dataset/maleeyes/803.jpg
#   inflating: ./dataset/maleeyes/804.jpg
#   inflating: ./dataset/maleeyes/805.jpg
#   inflating: ./dataset/maleeyes/806.jpg
#   inflating: ./dataset/maleeyes/807.jpg
#   inflating: ./dataset/maleeyes/808.jpg
#   inflating: ./dataset/maleeyes/809.jpg
#   inflating: ./dataset/maleeyes/81.jpg
#   inflating: ./dataset/maleeyes/810.jpg
#   inflating: ./dataset/maleeyes/811.jpg
#   inflating: ./dataset/maleeyes/812.jpg
#   inflating: ./dataset/maleeyes/813.jpg
#   inflating: ./dataset/maleeyes/814.jpg
#   inflating: ./dataset/maleeyes/815.jpg
#   inflating: ./dataset/maleeyes/816.jpg
#   inflating: ./dataset/maleeyes/817.jpg
#   inflating: ./dataset/maleeyes/818.jpg
#   inflating: ./dataset/maleeyes/819.jpg
#   inflating: ./dataset/maleeyes/82.jpg
#   inflating: ./dataset/maleeyes/821.jpg
#   inflating: ./dataset/maleeyes/822.jpg
#   inflating: ./dataset/maleeyes/823.jpg
#   inflating: ./dataset/maleeyes/824.jpg
#   inflating: ./dataset/maleeyes/825.jpg
#   inflating: ./dataset/maleeyes/826.jpg
#   inflating: ./dataset/maleeyes/827.jpg
#   inflating: ./dataset/maleeyes/829.jpg
#   inflating: ./dataset/maleeyes/83.jpg
#   inflating: ./dataset/maleeyes/830.jpg
#   inflating: ./dataset/maleeyes/831.jpg
#   inflating: ./dataset/maleeyes/832.jpg
#   inflating: ./dataset/maleeyes/833.jpg
#   inflating: ./dataset/maleeyes/834.jpg
#   inflating: ./dataset/maleeyes/835.jpg
#   inflating: ./dataset/maleeyes/836.jpg
#   inflating: ./dataset/maleeyes/837.jpg
#   inflating: ./dataset/maleeyes/838.jpg
#   inflating: ./dataset/maleeyes/839.jpg
#   inflating: ./dataset/maleeyes/84.jpg
#   inflating: ./dataset/maleeyes/840.jpg
#   inflating: ./dataset/maleeyes/843.jpg
#   inflating: ./dataset/maleeyes/844.jpg
#   inflating: ./dataset/maleeyes/845.jpg
#   inflating: ./dataset/maleeyes/846.jpg
#   inflating: ./dataset/maleeyes/847.jpg
#   inflating: ./dataset/maleeyes/848.jpg
#   inflating: ./dataset/maleeyes/849.jpg
#   inflating: ./dataset/maleeyes/85.jpg
#   inflating: ./dataset/maleeyes/852.jpg
#   inflating: ./dataset/maleeyes/853.jpg
#   inflating: ./dataset/maleeyes/854.jpg
#   inflating: ./dataset/maleeyes/855.jpg
#   inflating: ./dataset/maleeyes/856.jpg
#   inflating: ./dataset/maleeyes/857.jpg
#   inflating: ./dataset/maleeyes/858.jpg
#   inflating: ./dataset/maleeyes/859.jpg
#   inflating: ./dataset/maleeyes/86.jpg
#   inflating: ./dataset/maleeyes/861.jpg
#   inflating: ./dataset/maleeyes/862.jpg
#   inflating: ./dataset/maleeyes/863.jpg
#   inflating: ./dataset/maleeyes/864.jpg
#   inflating: ./dataset/maleeyes/865.jpg
#   inflating: ./dataset/maleeyes/866.jpg
#   inflating: ./dataset/maleeyes/867.jpg
#   inflating: ./dataset/maleeyes/868.jpg
#   inflating: ./dataset/maleeyes/87.jpg
#   inflating: ./dataset/maleeyes/870.jpg
#   inflating: ./dataset/maleeyes/871.jpg
#   inflating: ./dataset/maleeyes/872.jpg
#   inflating: ./dataset/maleeyes/873.jpg
#   inflating: ./dataset/maleeyes/874.jpg
#   inflating: ./dataset/maleeyes/875.jpg
#   inflating: ./dataset/maleeyes/877.jpg
#   inflating: ./dataset/maleeyes/878.jpg
#   inflating: ./dataset/maleeyes/879.jpg
#   inflating: ./dataset/maleeyes/88.jpg
#   inflating: ./dataset/maleeyes/880.jpg
#   inflating: ./dataset/maleeyes/881.jpg
#   inflating: ./dataset/maleeyes/882.jpg
#   inflating: ./dataset/maleeyes/883.jpg
#   inflating: ./dataset/maleeyes/884.jpg
#   inflating: ./dataset/maleeyes/885.jpg
#   inflating: ./dataset/maleeyes/886.jpg
#   inflating: ./dataset/maleeyes/887.jpg
#   inflating: ./dataset/maleeyes/888.jpg
#   inflating: ./dataset/maleeyes/889.jpg
#   inflating: ./dataset/maleeyes/89.jpg
#   inflating: ./dataset/maleeyes/890.jpg
#   inflating: ./dataset/maleeyes/891.jpg
#   inflating: ./dataset/maleeyes/892.jpg
#   inflating: ./dataset/maleeyes/893.jpg
#   inflating: ./dataset/maleeyes/894.jpg
#   inflating: ./dataset/maleeyes/895.jpg
#   inflating: ./dataset/maleeyes/896.jpg
#   inflating: ./dataset/maleeyes/897.jpg
#   inflating: ./dataset/maleeyes/898.jpg
#   inflating: ./dataset/maleeyes/90.jpg
#   inflating: ./dataset/maleeyes/900.jpg
#   inflating: ./dataset/maleeyes/901.jpg
#   inflating: ./dataset/maleeyes/903.jpg
#   inflating: ./dataset/maleeyes/904.jpg
#   inflating: ./dataset/maleeyes/907.jpg
#   inflating: ./dataset/maleeyes/908.jpg
#   inflating: ./dataset/maleeyes/909.jpg
#   inflating: ./dataset/maleeyes/91.jpg
#   inflating: ./dataset/maleeyes/910.jpg
#   inflating: ./dataset/maleeyes/911.jpg
#   inflating: ./dataset/maleeyes/912.jpg
#   inflating: ./dataset/maleeyes/913.jpg
#   inflating: ./dataset/maleeyes/914.jpg
#   inflating: ./dataset/maleeyes/915.jpg
#   inflating: ./dataset/maleeyes/916.jpg
#   inflating: ./dataset/maleeyes/917.jpg
#   inflating: ./dataset/maleeyes/918.jpg
#   inflating: ./dataset/maleeyes/919.jpg
#   inflating: ./dataset/maleeyes/92.jpg
#   inflating: ./dataset/maleeyes/920.jpg
#   inflating: ./dataset/maleeyes/921.jpg
#   inflating: ./dataset/maleeyes/922.jpg
#   inflating: ./dataset/maleeyes/923.jpg
#   inflating: ./dataset/maleeyes/924.jpg
#   inflating: ./dataset/maleeyes/925.jpg
#   inflating: ./dataset/maleeyes/926.jpg
#   inflating: ./dataset/maleeyes/927.jpg
#   inflating: ./dataset/maleeyes/928.jpg
#   inflating: ./dataset/maleeyes/929.jpg
#   inflating: ./dataset/maleeyes/93.jpg
#   inflating: ./dataset/maleeyes/930.jpg
#   inflating: ./dataset/maleeyes/931.jpg
#   inflating: ./dataset/maleeyes/932.jpg
#   inflating: ./dataset/maleeyes/933.jpg
#   inflating: ./dataset/maleeyes/934.jpg
#   inflating: ./dataset/maleeyes/935.jpg
#   inflating: ./dataset/maleeyes/936.jpg
#   inflating: ./dataset/maleeyes/937.jpg
#   inflating: ./dataset/maleeyes/938.jpg
#   inflating: ./dataset/maleeyes/939.jpg
#   inflating: ./dataset/maleeyes/94.jpg
#   inflating: ./dataset/maleeyes/940.jpg
#   inflating: ./dataset/maleeyes/941.jpg
#   inflating: ./dataset/maleeyes/942.jpg
#   inflating: ./dataset/maleeyes/943.jpg
#   inflating: ./dataset/maleeyes/944.jpg
#   inflating: ./dataset/maleeyes/946.jpg
#   inflating: ./dataset/maleeyes/947.jpg
#   inflating: ./dataset/maleeyes/948.jpg
#   inflating: ./dataset/maleeyes/949.jpg
#   inflating: ./dataset/maleeyes/95.jpg
#   inflating: ./dataset/maleeyes/950.jpg
#   inflating: ./dataset/maleeyes/951.jpg
#   inflating: ./dataset/maleeyes/952.jpg
#   inflating: ./dataset/maleeyes/953.jpg
#   inflating: ./dataset/maleeyes/954.jpg
#   inflating: ./dataset/maleeyes/955.jpg
#   inflating: ./dataset/maleeyes/956.jpg
#   inflating: ./dataset/maleeyes/957.jpg
#   inflating: ./dataset/maleeyes/958.jpg
#   inflating: ./dataset/maleeyes/959.jpg
#   inflating: ./dataset/maleeyes/96.jpg
#   inflating: ./dataset/maleeyes/960.jpg
#   inflating: ./dataset/maleeyes/961.jpg
#   inflating: ./dataset/maleeyes/962.jpg
#   inflating: ./dataset/maleeyes/963.jpg
#   inflating: ./dataset/maleeyes/964.jpg
#   inflating: ./dataset/maleeyes/965.jpg
#   inflating: ./dataset/maleeyes/966.jpg
#   inflating: ./dataset/maleeyes/967.jpg
#   inflating: ./dataset/maleeyes/968.jpg
#   inflating: ./dataset/maleeyes/969.jpg
#   inflating: ./dataset/maleeyes/97.jpg
#   inflating: ./dataset/maleeyes/970.jpg
#   inflating: ./dataset/maleeyes/971.jpg
#   inflating: ./dataset/maleeyes/972.jpg
#   inflating: ./dataset/maleeyes/973.jpg
#   inflating: ./dataset/maleeyes/977.jpg
#   inflating: ./dataset/maleeyes/978.jpg
#   inflating: ./dataset/maleeyes/979.jpg
#   inflating: ./dataset/maleeyes/98.jpg
#   inflating: ./dataset/maleeyes/980.jpg
#   inflating: ./dataset/maleeyes/982.jpg
#   inflating: ./dataset/maleeyes/983.jpg
#   inflating: ./dataset/maleeyes/986.jpg
#   inflating: ./dataset/maleeyes/987.jpg
#   inflating: ./dataset/maleeyes/988.jpg
#   inflating: ./dataset/maleeyes/989.jpg
#   inflating: ./dataset/maleeyes/99.jpg
#   inflating: ./dataset/maleeyes/990.jpg
#   inflating: ./dataset/maleeyes/991.jpg
#   inflating: ./dataset/maleeyes/992.jpg
#   inflating: ./dataset/maleeyes/993.jpg
#   inflating: ./dataset/maleeyes/995.jpg
#   inflating: ./dataset/maleeyes/996.jpg
#   inflating: ./dataset/maleeyes/997.jpg
#   inflating: ./dataset/maleeyes/998.jpg

# %% [markdown]
# ### Importing Packages
#
# Importing the NumPy, Pandas and Matplotlib, PyTorch Scikit-Image etc. packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tqdm.notebook as tqdm
import torch
from skimage.transform import resize
from skimage.io import imread


## This line makes matplotlib plot the figures inside the notebook
# %matplotlib inline

## Set some default values of the the matplotlib plots
plt.rcParams['figure.figsize'] = (8.0, 8.0)  # Set default plot's sizes
plt.rcParams['axes.grid'] = True  # Show grid by default in figures

# %% [markdown]
# ## Loading the Eyes Dataset
#
# We will use again the digits dataset from the last assignment.

# %%
from os.path import split
import glob
path = 'dataset'
path_img = list(glob.glob(path+'/**/*.jpg'))

labels = list(map(lambda x:split(split(x)[0])[1], path_img))
file_path = pd.Series(path_img, name='File_Path').astype(str)

labels = pd.Series(labels, name='Labels')
data = pd.concat([file_path, labels], axis=1)
data = data.sample(frac=1).reset_index(drop=True)
data.head()
# Out:
#                      File_Path      Labels
# 0     dataset/maleeyes/104.jpg    maleeyes
# 1    dataset/maleeyes/6323.jpg    maleeyes
# 2   dataset/femaleeyes/700.jpg  femaleeyes
# 3     dataset/maleeyes/570.jpg    maleeyes
# 4  dataset/femaleeyes/2177.jpg  femaleeyes

# %%
image_resize_shape = (64, 64, 3)
x = np.array([resize(imread(file_path), image_resize_shape, anti_aliasing=True) 
                for file_path in data.File_Path])
y = np.array([1 if label == "femaleeyes" else 0 for label in data.Labels])

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12, 8),
                        subplot_kw={'xticks': [], 'yticks': []})
for i, ax in enumerate(axes.flat):
    ax.imshow(x[i])
    ax.set_title(data.Labels[i])
plt.tight_layout()
plt.show()

# %%
counts = data.Labels.value_counts()
fig, ax = plt.subplots()
hbars = ax.barh([0, 1], counts, align='center')
ax.set_yticks([0, 1])
ax.set_yticklabels(("Male", "Female"))
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('Male - Female Distribution')
plt.show()
print("Male-Female Ratio = {}".format(counts[0]/counts[1]))
# Out:
# Male-Female Ratio = 1.2154940407535564

# %% [markdown]
# ## Train-Validation-Test split

# %%
n_samples = x.shape[0]  # The total number of samples in the dataset

## Generate a random generator with a fixed seed
rand_gen = np.random.RandomState(0)

## Generating a shuffled vector of indices
indices = np.arange(n_samples)
rand_gen.shuffle(indices)

## Split the indices into 60% train / 20% validation / 20% test
train_indices = indices[:int(0.6 * n_samples)]
val_indices = indices[int(0.6 * n_samples):int((0.6 + 0.2) * n_samples)]
test_indices = indices[int((0.6 + 0.2) * n_samples):]


## Extract the sub datasets from the full dataset using the calculated indices
x_train = x[train_indices]
y_train = y[train_indices]
x_val = x[val_indices]
y_val = y[val_indices]
x_test = x[test_indices]
y_test = y[test_indices]

# %% [markdown]
# ## Linear Logistic Regression
#
# We will start by rewriting the linear logistic regression model using PyTorch.
#
# **Reminder**: We are modeling the conditional distribution of the labels as:
#
# The way define and train models in PyTorch is by creating a class (which inherits the class of *torch.nn.Module*) and has two methods:
#
# - **\_\_init\_\_**: Which initialize the models layers with their parameters.
# - **forward**: which implements the model's functionality.
#
# We will implement the class using the following objects / functions from PyTorch:
#
# - [**torch.nn.Linear**](https://pytorch.org/docs/stable/nn.html#torch.nn.Linear): defines a linear layer with its parameters, $\Theta$. It is defined by the number of **input_features**, the number of **output_features**.
# - [**torch.nn.functional.log_softmax**](https://pytorch.org/docs/stable/nn.html#torch.nn.functional.log_softmax) which implements the log-softmax function.

# %%
class LinearLogisticRegression(torch.nn.Module):
     
    def __init__(self, in_features, out_features):   
        super(LinearLogisticRegression, self).__init__()
        
        ## Defining the linear function with it's parameters
        ## =================================================
        self.linear = torch.nn.Linear(in_features=in_features, out_features=out_features)
    
    def forward(self, x):
        x = x.view(x.shape[0], x.shape[1] * x.shape[2] * x.shape[3])
        z = self.linear(x)
        y = torch.nn.functional.log_softmax(z, dim=1)
        
        return y

# %% [markdown]
# ## Mini-Batch Gradient Decent
#
# In order to run over the dataset using mini batches PyTorch offers the class of [**torch.utils.data.DataLoader**](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) which receives a PyTorch dataset and generates a series of batches running over the dataset.
#
# To generate a PyTorch dataset from a tensor of x and a tensor of y we will use the following command:
#
# ```python
# torch.utils.data.TensorDataset(x, y)
# ```
#
# We will convert x_train into a float tensor and y_train into a long integer tensor.

# %%
batch_size = 256
train_set = torch.utils.data.TensorDataset(torch.tensor(x_train).float(), torch.tensor(y_train).long())
train_loader = torch.utils.data.DataLoader(dataset=train_set, batch_size=batch_size, shuffle=True)

# %% [markdown]
# The following function implement mini-batch gradient descent using:
#
# - The built-in optimization object [**torch.optim.SGD**](https://pytorch.org/docs/stable/optim.html#torch.optim.SGD) which performs gradient descent steps on a given set of parameters.
# - The built-in loss function [**torch.nn.functional.nll_loss**](https://pytorch.org/docs/stable/nn.html#torch.nn.functional.nll_loss) which calculates the negative log-likelihood of a matrix of log-probabilities, $P$, and a vector of labels, $\boldsymbol{y}$ : $-\frac{1}{N}\sum_iP_{i,y_i}$

# %%
def train(model, eta, n_epochs, train_loader, x_val, y_val):
    ## Move validation set to the GPU
    x_val = x_val.cuda()
    y_val = y_val.cuda()
    
    ## Initizalie the optimizer
    optimizer = torch.optim.SGD(model.parameters(), lr=eta)

    ## Prepare lists to store intermediate obejectives
    train_objective_list = [np.inf]
    val_objective_list = [np.inf]
    
    ## Run for n_epochs
    for epoch in tqdm.tqdm(range(n_epochs)):
        ## Run over the batches
        for x, y in train_loader:

            ## Move batch to GPU
            x = x.cuda()
            y = y.cuda()
            
            optimizer.zero_grad()
            ## Forward pass
            py_hat = model(x)
            objective = torch.nn.functional.nll_loss(py_hat, y)
            ## Backward pass
            objective.backward()
            ## Preform the gradient descent step
            optimizer.step()
    
        ## Evaluate the objective on the validation set
        with torch.no_grad(): ## This tell PyTorch not to calculate the gradients to save time
            train_objective_list.append(objective.item())

            py_hat = model(x_val)
            objective = torch.nn.functional.nll_loss(py_hat, y_val)
            val_objective_list.append(objective.item())

    return train_objective_list, val_objective_list

## Test the train function
eta = 0.001
n_epochs = 10
model = LinearLogisticRegression(in_features=x_train.shape[1] * x_train.shape[2] * x_train.shape[3], out_features=2)
try:
  model = model.cuda()
except:
  print("No gpu found, using cpu")
train_objective_list, val_objective_list = train(model, eta, n_epochs, train_loader,
                                                 torch.tensor(x_val).float(),
                                                 torch.tensor(y_val).long())

## Plot
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(np.arange(len(train_objective_list)), train_objective_list, label='Train')
ax.plot(np.arange(len(val_objective_list)), val_objective_list, label='Validation')
ax.set_title(r'$\eta={' + f'{eta:g}' + r'}$')
ax.set_xlabel('Step')
ax.set_ylabel('Objective')
ax.legend();
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ### Selecting the learning rate

# %%
n_epochs = 100
etas_list = (1e-2, 3e-2, 1e-3, 3e-4)

fig, axes = plt.subplots(2, 2, figsize=(6, 6))
for i_eta, eta in enumerate(etas_list):
    model = LinearLogisticRegression(in_features=x_train.shape[1] * x_train.shape[2] * x_train.shape[3], out_features=2)
    model = model.cuda()
    train_objective_list, val_objective_list = train(model, eta, n_epochs, train_loader,
                                                     torch.tensor(x_val).float(),
                                                     torch.tensor(y_val).long())

    ## Plot
    ax = axes.flat[i_eta]
    ax.plot(np.arange(len(train_objective_list)), train_objective_list, label='Train')
    ax.plot(np.arange(len(val_objective_list)), val_objective_list, label='Validation')
    ax.set_title(r'$\eta={' + f'{eta:g}' + r'}$')
    ax.set_xlabel('Step')
    ax.set_ylabel('Objective')
axes[1,1].legend()
fig.tight_layout()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# Selecting the largest learning rate $\eta$

# %%
eta = 0.001
n_epochs = 200
model = LinearLogisticRegression(in_features=x_train.shape[1] * x_train.shape[2] * x_train.shape[3], out_features=2)
model = model.cuda()
train_objective_list, val_objective_list = train(model, eta, n_epochs, train_loader,
                                                 torch.tensor(x_val).float(),
                                                 torch.tensor(y_val).long())

## Plot
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(np.arange(len(train_objective_list)), train_objective_list, label='Train')
ax.plot(np.arange(len(val_objective_list)), val_objective_list, label='Validation')
ax.set_title(r'$\eta={' + f'{eta:g}' + r'}$')
ax.set_xlabel('Step')
ax.set_ylabel('Objective')
ax.set_ylim(0, 0.5)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# (0.0, 0.5)

# %% [markdown]
# ### Early Stopping
#
# We would like to stop the training when the validation objective reaches its minimum.

# %%
optimal_number_of_steps = np.argmin(val_objective_list)
print(optimal_number_of_steps)

model = LinearLogisticRegression(in_features=x_train.shape[1] * x_train.shape[2] * x_train.shape[3], out_features=2)
model = model.cuda()
train_objective_list, val_objective_list = train(model, eta, optimal_number_of_steps, train_loader,
                                                 torch.tensor(x_val).float(),
                                                 torch.tensor(y_val).long())

## Plot
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(np.arange(len(train_objective_list)), train_objective_list, label='Train')
ax.plot(np.arange(len(val_objective_list)), val_objective_list, label='Validation')
ax.set_title(r'$\eta={' + f'{eta:g}' + r'}$')
ax.set_xlabel('Step')
ax.set_ylabel('Objective')
ax.set_ylim(0, 0.5);
# Out:
# 199
#   0%|          | 0/199 [00:00<?, ?it/s]

# %% [markdown]
# ### Evaluating the Model on the Test Set
#
# The following code calculates the misclassification rate on the test set.
#
# In order to so we will define a data loader on the test set.

# %%
test_set = torch.utils.data.TensorDataset(torch.tensor(x_test).float(), torch.tensor(y_test).long())
test_loader = torch.utils.data.DataLoader(dataset=test_set, batch_size=batch_size)

## Evaluate the score on the test set
with torch.no_grad():
    test_score_list = []
    for x, y in test_loader:
        x = x.cuda()
        y = y.cuda()

        y_hat = model(x)
        test_score = (torch.argmax(y_hat, dim=1) != y).sum()

        test_score_list.append(test_score.item())

test_score = np.sum(test_score_list) / len(test_set)

print(f'Linear Logistic Regression test score is: {test_score:.3}')
# Out:
# The test score is: 0.243

# %% [markdown]
# ## MLP
#
# Now that we have a training function and we know have some naive model we can try a bit more complex models.
#
# Specifically, we will run one MLP network and one CNN network.
#
# I.e., build a network with of the following layers:
#
# - **fc1**: A fully connected (linear) layer with an input of the in_features and output of 1024 with a ReLU activation.
# - **fc2**: A fully connected of 1024x1024 + ReLU.
# - **fc3**: A fully connected of 1024xout_features.
# - A softmax function
#
# In our case:
#
# - in_features = 64*64*3
# - out_features = 2
#
# We will use the function [**torch.nn.functional.relu**](https://pytorch.org/docs/stable/nn.functional.html#torch.nn.functional.relu) to implement the ReLU activation.

# %%
class MLP(torch.nn.Module):

    def __init__(self, in_features, out_features):   
        super(MLP, self).__init__()
        
        ## Defining the fully connected (linear) layers with their parameters
        ## ==================================================================
        self.linear1 = torch.nn.Linear(in_features=in_features, out_features=1024, bias=True)
        self.linear2 = torch.nn.Linear(in_features=1024, out_features=1024, bias=True)
        self.linear3 = torch.nn.Linear(in_features=1024, out_features=out_features, bias=True)
    
    def forward(self, x):
        x = x.view(x.shape[0], x.shape[1] * x.shape[2] * x.shape[3])
        z = self.linear1(x)
        z = torch.nn.functional.relu(z)
        z = self.linear2(z)
        z = torch.nn.functional.relu(z)
        z = self.linear3(z)
        y = torch.nn.functional.log_softmax(z, dim=1)
        
        return y

## Test the train function
eta = 0.0001
n_epochs = 50
model = MLP(in_features=x_train.shape[1] * x_train.shape[2] * x_train.shape[3], out_features=2)
model = model.cuda()
train_objective_list, val_objective_list = train(model, eta, n_epochs, train_loader,
                                                 torch.tensor(x_val).float(),
                                                 torch.tensor(y_val).long())

## Plot
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(np.arange(len(train_objective_list)), train_objective_list, label='Train')
ax.plot(np.arange(len(val_objective_list)), val_objective_list, label='Validation')
ax.set_title(r'$\eta={' + f'{eta:g}' + r'}$')
ax.set_xlabel('Step')
ax.set_ylabel('Objective');
ax.legend()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# ### Selecting the learning rate

# %%
n_epochs = 350
etas_list = (1e-3, 3e-4)

fig, axes = plt.subplots(2, 1, figsize=(6, 6))
for i_eta, eta in enumerate(etas_list):
    model = MLP(in_features=x_train.shape[1] * x_train.shape[2] * x_train.shape[3], out_features=2)
    model = model.cuda()
    train_objective_list, val_objective_list = train(model, eta, n_epochs, train_loader,
                                                     torch.tensor(x_val).float(),
                                                     torch.tensor(y_val).long())
    
    ## Plot
    ax = axes.flat[i_eta]
    ax.plot(np.arange(len(train_objective_list)), train_objective_list, label='Train')
    ax.plot(np.arange(len(val_objective_list)), val_objective_list, label='Validation')
    ax.set_title(r'$\eta={' + f'{eta:g}' + r'}$')
    ax.set_xlabel('Step')
    ax.set_ylabel('Objective')
axes[1].legend()
fig.tight_layout()
# Out:
#   0%|          | 0/350 [00:00<?, ?it/s]
#   0%|          | 0/350 [00:00<?, ?it/s]

# %% [markdown]
# We choose $\eta=3e-4$ and train the model for 500 epochs.

# %%
eta = 3e-4
n_epochs = 500
model = MLP(in_features=x_train.shape[1] * x_train.shape[2] * x_train.shape[3], out_features=2)
model = model.cuda()
train_objective_list, val_objective_list = train(model, eta, n_epochs, train_loader,
                                                  torch.tensor(x_val).float(),
                                                  torch.tensor(y_val).long())

## Plot
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(np.arange(len(train_objective_list)), train_objective_list, label='Train')
ax.plot(np.arange(len(val_objective_list)), val_objective_list, label='Validation')
ax.set_title(r'$\eta={' + f'{eta:g}' + r'}$')
ax.set_xlabel('Step')
ax.set_ylabel('Objective')
ax.legend()
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Text(0, 0.5, 'Objective')

# %% [markdown]
# ### Early Stopping
#
# We would like to stop the training when the validation objective reaches its minimum.

# %%
optimal_number_of_steps = np.argmin(train_objective_list)
print(optimal_number_of_steps)
model = MLP(in_features=x_train.shape[1] * x_train.shape[2] * x_train.shape[3], out_features=2)
model = model.cuda()
train_objective_list, val_objective_list = train(model, eta, optimal_number_of_steps, train_loader,
                                                  torch.tensor(x_val).float(),
                                                  torch.tensor(y_val).long())

## Plot
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(np.arange(len(train_objective_list)), train_objective_list, label='Train')
ax.plot(np.arange(len(val_objective_list)), val_objective_list, label='Validation')
ax.set_title(r'$\eta={' + f'{eta:g}' + r'}$')
ax.set_xlabel('Step')
ax.set_ylabel('Objective')
ax.set_ylim(0, 0.6);
ax.legend()
# Out:
# 495
#   0%|          | 0/495 [00:00<?, ?it/s]

# %% [markdown]
# ### Evaluating the Model on the Test Set

# %%
with torch.no_grad():
    test_score_list = []
    for x, y in test_loader:
        x = x.cuda()
        y = y.cuda()

        y_hat = model(x)
        test_score = (torch.argmax(y_hat, dim=1) != y).sum()

        test_score_list.append(test_score.item())

test_score = np.sum(test_score_list) / len(test_set)

print(f'MLP Model test score is: {test_score:.3}')
# Out:
# MLP Model test score is: 0.206

# %% [markdown]
# ## CNN
#
# We will now also implement a CNN network.
#
# In the code below we define a CNN which is composed of the following layers:
#
# - **conv1**: A convolutional layer with a 3x3 kernel, 3 input channels, 64 output channels, a padding of 1 on each edge + ReLU.
# - **conv2**: A convolutional layer with a 3x3 kernel, 64 input, 64 output, padding of 1, **stride of 2** + ReLU.
# - **fc3**: A fully connected of (32\*32\*64)x256 + ReLU.
# - **fc4**: A fully connected of 256x2.
# - A softmax function

# %%
class CNN(torch.nn.Module):

    def __init__(self, in_features, out_features):   
        super(CNN, self).__init__()
        
        ## Defining the convolutional and fully connected layers with their parameters
        ## ===========================================================================
        self.bn0 = torch.nn.BatchNorm2d(3)
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, padding=1)
        self.conv2 = torch.nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1, stride=2)
        self.fc3 = torch.nn.Linear(in_features=32*32*64, out_features=256)
        self.fc4 = torch.nn.Linear(in_features=256, out_features=out_features)
    
    def forward(self, x):
        x = x.transpose(1,3)
        z = self.bn0(x)
        z = self.conv1(z)
        z = torch.nn.functional.relu(z)
        z = self.conv2(z)
        z = torch.nn.functional.relu(z)
        z = z.view(z.shape[0], -1)
        z = self.fc3(z)
        z = torch.nn.functional.relu(z)
        z = self.fc4(z)
        y = torch.nn.functional.log_softmax(z, dim=1)
        return y

## Test the train function
eta = 0.001
n_epochs = 30
model = CNN(in_features=x_train.shape[1] * x_train.shape[2], out_features=2)
model = model.cuda()
train_objective_list, val_objective_list = train(model, eta, n_epochs, train_loader,
                                                 torch.tensor(x_val).float(),
                                                 torch.tensor(y_val).long())

## Plot
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(np.arange(len(train_objective_list)), train_objective_list, label='Train')
ax.plot(np.arange(len(val_objective_list)), val_objective_list, label='Validation')
ax.set_title(r'$\eta={' + f'{eta:g}' + r'}$')
ax.set_xlabel('Step')
ax.set_ylabel('Objective');
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
nn_epochs = 30
etas_list = (0.01, 3e-3, 1e-3, 3e-4)

fig, axes = plt.subplots(2, 2, figsize=(6, 6))
for i_eta, eta in enumerate(etas_list):
    model = CNN(in_features=x_train.shape[1] * x_train.shape[2], out_features=10)
    model = model.cuda()
    train_objective_list, val_objective_list = train(model, eta, nn_epochs, train_loader,
                                                     torch.tensor(x_val).float(),
                                                     torch.tensor(y_val).long())
    
    ## Plot
    ax = axes.flat[i_eta]
    ax.plot(np.arange(len(train_objective_list)), train_objective_list, label='Train')
    ax.plot(np.arange(len(val_objective_list)), val_objective_list, label='Validation')
    ax.set_title(r'$\eta={' + f'{eta:g}' + r'}$')
    ax.set_xlabel('Step')
    ax.set_ylabel('Objective')
axes[1,1].legend()
fig.tight_layout()
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]

# %% [markdown]
# Choosing $\eta=0.0003$

# %%
eta = 0.0003
n_epochs = 200
model = CNN(in_features=x_train.shape[1] * x_train.shape[2], out_features=10)
model = model.cuda()
train_objective_list, val_objective_list = train(model, eta, n_epochs, train_loader,
                                                  torch.tensor(x_val).float(),
                                                  torch.tensor(y_val).long())

## Plot
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(np.arange(len(train_objective_list)), train_objective_list, label='Train')
ax.plot(np.arange(len(val_objective_list)), val_objective_list, label='Validation')
ax.set_title(r'$\eta={' + f'{eta:g}' + r'}$')
ax.set_xlabel('Step')
ax.set_ylabel('Objective');
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
optimal_number_of_steps = np.argmin(val_objective_list)
print(optimal_number_of_steps)

eta = 0.0003
n_epochs = optimal_number_of_steps
model = CNN(in_features=x_train.shape[1] * x_train.shape[2], out_features=2)
model = model.cuda()
train_objective_list, val_objective_list = train(model, eta, n_epochs, train_loader,
                                                  torch.tensor(x_val).float(),
                                                  torch.tensor(y_val).long())

## Plot
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(np.arange(len(train_objective_list)), train_objective_list, label='Train')
ax.plot(np.arange(len(val_objective_list)), val_objective_list, label='Validation')
ax.set_title(r'$\eta={' + f'{eta:g}' + r'}$')
ax.set_xlabel('Step')
ax.set_ylabel('Objective');
# Out:
# 198
#   0%|          | 0/198 [00:00<?, ?it/s]

# %%
test_set = torch.utils.data.TensorDataset(torch.tensor(x_test).float(), torch.tensor(y_test).long())
test_loader = torch.utils.data.DataLoader(dataset=test_set, batch_size=batch_size)
with torch.no_grad():
    test_score_list = []
    for x, y in test_loader:
        x = x.cuda()
        y = y.cuda()

        y_hat = model(x)
        test_score = (torch.argmax(y_hat, dim=1) != y).sum()

        test_score_list.append(test_score.item())

test_score = np.sum(test_score_list) / len(test_set)

print(f'The test score is: {test_score:.3}')
# Out:
# The test score is: 0.17
